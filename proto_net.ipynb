# %%
import os
import cv2
import numpy as np
from glob import glob
from tqdm import tqdm
import matplotlib.pyplot as plt
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Lambda, Dense, Dropout, Conv2D, MaxPooling2D, Flatten,Activation,BatchNormalization
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.losses import CategoricalCrossentropy

from tensorflow.keras.applications.efficientnet import preprocess_input,EfficientNetB0

from tensorflow.keras import callbacks as cb
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from sklearn.model_selection import train_test_split

gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth( device=gpu, enable=True)

# %%
all_classes = glob('/home/jovyan/data/fungi/images/*')
source_classes,target_classes=train_test_split(all_classes,test_size=0.1)
sorce_len=len(source_classes)
target_len=len(target_classes)
print(f"total {len(all_classes)} classes=source {sorce_len} + target {target_len} classes")
# Out:
# total 1394 classes=source 1254 + target 140 classes

# %%
W,H,CH = 224,224,3
# W,H,CH = 64,64,3
def load_img(path, width = W):
#     img = cv2.cvtColor(cv2.imread(path), cv2.COLOR_BGR2RGB).astype(np.float32)/255.0
    img = tf.io.read_file(path)
#     img = tf.image.decode_jpeg(img, channels=CH)
    img = tf.image.decode_jpeg(img, channels=CH)/255
    img = img.numpy()
    
    shape_dst = np.min(img.shape[:2])
    oh = (img.shape[0] - shape_dst) // 2
    ow = (img.shape[1] - shape_dst) // 2
    center_square = np.array([width,width])// 2
    new_size=(width,width)
    
    # cropping + resize
    img = img[oh:oh + shape_dst, ow:ow + shape_dst]
    img=cv2.resize(img, new_size)
    
    # Random affine+rotation
#     random_state = np.random.RandomState(seed=None)
#     alpha_affine=img.shape[0] * 0.1
#     pts1 = np.float32([center_square + width, 
#                        [center_square[0]+width, center_square[1]-width],
#                        center_square - width])
#     pts2 = pts1 + random_state.uniform(-alpha_affine, alpha_affine, size=pts1.shape).astype(np.float32)
#     M = cv2.getAffineTransform(pts1, pts2)
#     rot_mat = cv2.getRotationMatrix2D(tuple(center_square),random_state.rand()*360., 1.0)
#     img = cv2.warpAffine(img, M, new_size, borderMode=cv2.BORDER_REPLICATE)
#     img = cv2.warpAffine(img, rot_mat, new_size, borderMode=cv2.BORDER_REPLICATE)
    return tf.constant(img)

# %%
WAYS = 3
SHOTS=5
QUERIES=1
BATCH_SIZE=4

# %%
min([len(glob(sdir+'/*.JPG')) for sdir in source_classes])
# Out:
# 6

# %%
## exclude classes with too few examples
source_classes=[sdir for sdir in source_classes if len(glob(sdir+'/*.JPG'))>SHOTS+QUERIES]

sorce_len=len(source_classes)
print(f"source {sorce_len} + target {target_len} classes")
# Out:
# source 1244 + target 140 classes

# %%
min([len(glob(sdir+'/*.JPG')) for sdir in source_classes])
# Out:
# 7

# %%
map_fun=lambda string: tf.py_function(func=load_img,inp=[string], Tout=tf.float32)
all_sub = [
    tf.data.Dataset.list_files(sc+'/*.JPG', shuffle=True)
    .map(map_fun)
    for sc in source_classes
]

def gen():
    supports = []
    querys = []
    order=np.random.permutation(len(all_sub))
    for tasks in range(len(all_sub)//WAYS):
        picked=[all_sub[tt] for tt in order[WAYS*tasks:WAYS*(tasks+1)]]
        support = tf.concat(
            [
                next(
                    iter(
                        sub.batch(SHOTS).prefetch(SHOTS)
                    )
                    ) for sub in picked
            ]
            , axis=0)
        idxs=np.random.choice(range(WAYS), size=QUERIES, replace=False)
        query = tf.concat(
            [
                next(
                    iter(
                        picked[idx].batch(1).prefetch(1)
                    )
                    ) for idx in idxs
            ]
            , axis=0)
        yield tf.concat([support, query], axis=0), tuple([keras.utils.to_categorical(idx,num_classes=WAYS) for idx in idxs])
dd = tf.data.Dataset.from_generator(gen,
                                    output_types=(tf.float32,tuple([tf.float32]*QUERIES)),
                                    output_shapes=((WAYS*SHOTS+QUERIES,W,H,CH),tuple([WAYS]*QUERIES))
                                   ).batch(BATCH_SIZE)

# %%
def conv_net(input_shape):
    convnet = Sequential()
    for i in range(4):
        convnet.add(Conv2D(64,(3,3),padding='valid',input_shape=input_shape))
        convnet.add(BatchNormalization())
        convnet.add(Activation('relu'))
        convnet.add(MaxPooling2D())
    convnet.add(Flatten())
    return convnet
def pretrain_net(input_shape):
    base_model = EfficientNetB0(weights="imagenet", include_top=False)
    x_in=Input(shape=(W,H,CH))
    x=preprocess_input(x_in)
    out=Flatten()(base_model(x))
    model = Model(inputs=x_in, outputs=out)
    return model
def euclidean_distance(f_1,f_2):
    """
    Euclidean distance loss
    https://en.wikipedia.org/wiki/Euclidean_distance
    :param y_true: TensorFlow/Theano tensor
    :param y_pred: TensorFlow/Theano tensor of the same shape as y_true
    :return: float
    """
    return K.sqrt(K.sum(K.square(f_1 - f_2), axis=-1))

# %%
base_dim = (W,H,CH)
base_network = pretrain_net(base_dim)
# Query feature
x_in=Input(shape=(WAYS*SHOTS+QUERIES,W,H,CH))
latent_s=[base_network(x_in[:,ii]) for ii in range(WAYS*SHOTS)]
latent_q=[base_network(x_in[:,WAYS*SHOTS+ii]) for ii in range(QUERIES)]

y=list()
for qq in range(QUERIES):
    dist_scores=list()
    for ww in range(WAYS):
        latent_proto=tf.reduce_mean(tf.stack(latent_s[ww*SHOTS:(ww+1)*SHOTS],axis=-1),axis=-1)
        dist_avg=euclidean_distance(latent_q[qq],latent_proto)
        dist_scores.append(dist_avg)
    y.append(tf.nn.softmax(-tf.stack(dist_scores,axis=-1),axis=-1))

model = Model(inputs=x_in, outputs=tuple(y))

# %%
lr=0.001
def scheduler(epoch):
    global lr
    if epoch % 3 == 0:
        lr /= 2
    return lr
reduce_lr = cb.ReduceLROnPlateau(monitor='loss', factor=0.4,patience=2, min_lr=1e-8)
lr_sched = cb.LearningRateScheduler(scheduler)
tensorboard = cb.TensorBoard()
opt = tf.keras.optimizers.Adam(lr=0.002)
model.compile(loss=CategoricalCrossentropy(), optimizer=opt, metrics=['categorical_accuracy'])

# %%
# %%time
model.fit(dd, epochs=1000, verbose=1,workers=4, callbacks=[reduce_lr,lr_sched, tensorboard])
# Out:
# Epoch 1/1000
#       1/Unknown - 0s 69us/step - loss: 10.0511 - categorical_accuracy: 0.0000e+00WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 104/104 [==============================] - 151s 1s/step - loss: 1.3028 - categorical_accuracy: 0.6353
# Epoch 2/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.8724 - categorical_accuracy: 0.6763
# Epoch 3/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.8460 - categorical_accuracy: 0.6860
# Epoch 4/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9195 - categorical_accuracy: 0.6618
# Epoch 5/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.8246 - categorical_accuracy: 0.6884
# Epoch 6/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.8180 - categorical_accuracy: 0.6908
# Epoch 7/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7189 - categorical_accuracy: 0.7150
# Epoch 8/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7036 - categorical_accuracy: 0.7222
# Epoch 9/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7210 - categorical_accuracy: 0.7271
# Epoch 10/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6633 - categorical_accuracy: 0.7101
# Epoch 11/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6259 - categorical_accuracy: 0.7343
# Epoch 12/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6879 - categorical_accuracy: 0.7222
# Epoch 13/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6545 - categorical_accuracy: 0.7367
# Epoch 14/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7485 - categorical_accuracy: 0.6836
# Epoch 15/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6394 - categorical_accuracy: 0.7536
# Epoch 16/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6867 - categorical_accuracy: 0.7246
# Epoch 17/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6646 - categorical_accuracy: 0.7440
# Epoch 18/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7123 - categorical_accuracy: 0.7005
# Epoch 19/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6182 - categorical_accuracy: 0.7367
# Epoch 20/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6463 - categorical_accuracy: 0.7415
# Epoch 21/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6071 - categorical_accuracy: 0.7198
# Epoch 22/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.6462 - categorical_accuracy: 0.7343
# Epoch 23/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5845 - categorical_accuracy: 0.7633
# Epoch 24/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6369 - categorical_accuracy: 0.7150
# Epoch 25/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5819 - categorical_accuracy: 0.7633
# Epoch 26/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7275 - categorical_accuracy: 0.6908
# Epoch 27/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6592 - categorical_accuracy: 0.7295
# Epoch 28/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6196 - categorical_accuracy: 0.7464
# Epoch 29/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6669 - categorical_accuracy: 0.7150
# Epoch 30/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6185 - categorical_accuracy: 0.7585
# Epoch 31/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.5813 - categorical_accuracy: 0.7488
# Epoch 32/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6511 - categorical_accuracy: 0.7246
# Epoch 33/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5918 - categorical_accuracy: 0.7585
# Epoch 34/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6212 - categorical_accuracy: 0.7415
# Epoch 35/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5935 - categorical_accuracy: 0.7657
# Epoch 36/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6626 - categorical_accuracy: 0.7440
# Epoch 37/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6903 - categorical_accuracy: 0.7198
# Epoch 38/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6002 - categorical_accuracy: 0.7415
# Epoch 39/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6395 - categorical_accuracy: 0.7343
# Epoch 40/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.5921 - categorical_accuracy: 0.7488
# Epoch 41/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6646 - categorical_accuracy: 0.7319
# Epoch 42/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.7110 - categorical_accuracy: 0.7126
# Epoch 43/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7320 - categorical_accuracy: 0.6908
# Epoch 44/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6110 - categorical_accuracy: 0.7440
# Epoch 45/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5593 - categorical_accuracy: 0.7560
# Epoch 46/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6023 - categorical_accuracy: 0.7367
# Epoch 47/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6307 - categorical_accuracy: 0.7101
# Epoch 48/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6593 - categorical_accuracy: 0.7126
# Epoch 49/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5757 - categorical_accuracy: 0.7512
# Epoch 50/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6047 - categorical_accuracy: 0.7440
# Epoch 51/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6449 - categorical_accuracy: 0.7246
# Epoch 52/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7953 - categorical_accuracy: 0.6763
# Epoch 53/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5786 - categorical_accuracy: 0.7536
# Epoch 54/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6645 - categorical_accuracy: 0.7174
# Epoch 55/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6355 - categorical_accuracy: 0.7319
# Epoch 56/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6253 - categorical_accuracy: 0.7319
# Epoch 57/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6165 - categorical_accuracy: 0.7633
# Epoch 58/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6206 - categorical_accuracy: 0.7391
# Epoch 59/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6336 - categorical_accuracy: 0.7222
# Epoch 60/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5667 - categorical_accuracy: 0.7440
# Epoch 61/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5937 - categorical_accuracy: 0.7391
# Epoch 62/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6221 - categorical_accuracy: 0.7222
# Epoch 63/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6793 - categorical_accuracy: 0.7343
# Epoch 64/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6380 - categorical_accuracy: 0.7464
# Epoch 65/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6457 - categorical_accuracy: 0.7391
# Epoch 66/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5622 - categorical_accuracy: 0.7585
# Epoch 67/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.6641 - categorical_accuracy: 0.7150
# Epoch 68/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6513 - categorical_accuracy: 0.7222
# Epoch 69/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.5580 - categorical_accuracy: 0.7609
# Epoch 70/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7012 - categorical_accuracy: 0.7005
# Epoch 71/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6809 - categorical_accuracy: 0.7150
# Epoch 72/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6451 - categorical_accuracy: 0.7101
# Epoch 73/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6476 - categorical_accuracy: 0.7464
# Epoch 74/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6885 - categorical_accuracy: 0.7295
# Epoch 75/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7095 - categorical_accuracy: 0.7174
# Epoch 76/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6873 - categorical_accuracy: 0.7343
# Epoch 77/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6333 - categorical_accuracy: 0.7391
# Epoch 78/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6412 - categorical_accuracy: 0.7512
# Epoch 79/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6208 - categorical_accuracy: 0.7367
# Epoch 80/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6207 - categorical_accuracy: 0.7295
# Epoch 81/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6027 - categorical_accuracy: 0.7246
# Epoch 82/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5897 - categorical_accuracy: 0.7512
# Epoch 83/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6065 - categorical_accuracy: 0.7826
# Epoch 84/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6389 - categorical_accuracy: 0.7150
# Epoch 85/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6259 - categorical_accuracy: 0.7295
# Epoch 86/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6228 - categorical_accuracy: 0.7367
# Epoch 87/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6850 - categorical_accuracy: 0.7126
# Epoch 88/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6410 - categorical_accuracy: 0.7077
# Epoch 89/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5783 - categorical_accuracy: 0.7633
# Epoch 90/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6354 - categorical_accuracy: 0.7367
# Epoch 91/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7087 - categorical_accuracy: 0.7295
# Epoch 92/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5622 - categorical_accuracy: 0.7560
# Epoch 93/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6721 - categorical_accuracy: 0.7271
# Epoch 94/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6250 - categorical_accuracy: 0.7488
# Epoch 95/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6287 - categorical_accuracy: 0.7560
# Epoch 96/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6498 - categorical_accuracy: 0.7101
# Epoch 97/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6441 - categorical_accuracy: 0.7271
# Epoch 98/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6579 - categorical_accuracy: 0.7150
# Epoch 99/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6700 - categorical_accuracy: 0.7464
# Epoch 100/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7078 - categorical_accuracy: 0.6836
# Epoch 101/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6550 - categorical_accuracy: 0.7271
# Epoch 102/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5819 - categorical_accuracy: 0.7681
# Epoch 103/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6367 - categorical_accuracy: 0.7319
# Epoch 104/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6584 - categorical_accuracy: 0.7464
# Epoch 105/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6145 - categorical_accuracy: 0.7367
# Epoch 106/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6166 - categorical_accuracy: 0.7415
# Epoch 107/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6277 - categorical_accuracy: 0.7367
# Epoch 108/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6401 - categorical_accuracy: 0.7319
# Epoch 109/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6320 - categorical_accuracy: 0.7295
# Epoch 110/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6546 - categorical_accuracy: 0.7150
# Epoch 111/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6190 - categorical_accuracy: 0.7415
# Epoch 112/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6520 - categorical_accuracy: 0.7198
# Epoch 113/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.6007 - categorical_accuracy: 0.7536
# Epoch 114/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6324 - categorical_accuracy: 0.7343
# Epoch 115/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7670 - categorical_accuracy: 0.6908
# Epoch 116/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6051 - categorical_accuracy: 0.7560
# Epoch 117/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6617 - categorical_accuracy: 0.7271
# Epoch 118/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5810 - categorical_accuracy: 0.7343
# Epoch 119/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5915 - categorical_accuracy: 0.7440
# Epoch 120/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5953 - categorical_accuracy: 0.7633
# Epoch 121/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7310 - categorical_accuracy: 0.6932
# Epoch 122/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7121 - categorical_accuracy: 0.7174
# Epoch 123/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6773 - categorical_accuracy: 0.7343
# Epoch 124/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5970 - categorical_accuracy: 0.7367
# Epoch 125/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.5718 - categorical_accuracy: 0.7585
# Epoch 126/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6912 - categorical_accuracy: 0.7150
# Epoch 127/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6880 - categorical_accuracy: 0.7198
# Epoch 128/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5668 - categorical_accuracy: 0.7657
# Epoch 129/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5878 - categorical_accuracy: 0.7488
# Epoch 130/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6436 - categorical_accuracy: 0.7609
# Epoch 131/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6411 - categorical_accuracy: 0.7246
# Epoch 132/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6015 - categorical_accuracy: 0.7560
# Epoch 133/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.5111 - categorical_accuracy: 0.8092
# Epoch 134/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5966 - categorical_accuracy: 0.7222
# Epoch 135/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6064 - categorical_accuracy: 0.7415
# Epoch 136/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6288 - categorical_accuracy: 0.7585
# Epoch 137/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5335 - categorical_accuracy: 0.7802
# Epoch 138/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6427 - categorical_accuracy: 0.7440
# Epoch 139/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5939 - categorical_accuracy: 0.7512
# Epoch 140/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6298 - categorical_accuracy: 0.7367
# Epoch 141/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6438 - categorical_accuracy: 0.7415
# Epoch 142/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6109 - categorical_accuracy: 0.7585
# Epoch 143/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6313 - categorical_accuracy: 0.7295
# Epoch 144/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6753 - categorical_accuracy: 0.7440
# Epoch 145/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6564 - categorical_accuracy: 0.7609
# Epoch 146/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6364 - categorical_accuracy: 0.7343
# Epoch 147/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6571 - categorical_accuracy: 0.7271
# Epoch 148/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6070 - categorical_accuracy: 0.7609
# Epoch 149/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6185 - categorical_accuracy: 0.7633
# Epoch 150/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5967 - categorical_accuracy: 0.7415
# Epoch 151/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5976 - categorical_accuracy: 0.7488
# Epoch 152/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6356 - categorical_accuracy: 0.7415
# Epoch 153/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6584 - categorical_accuracy: 0.7343
# Epoch 154/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7566 - categorical_accuracy: 0.6667
# Epoch 155/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5864 - categorical_accuracy: 0.7512
# Epoch 156/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5230 - categorical_accuracy: 0.7657
# Epoch 157/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6685 - categorical_accuracy: 0.7198
# Epoch 158/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6171 - categorical_accuracy: 0.7464
# Epoch 159/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6227 - categorical_accuracy: 0.7295
# Epoch 160/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6908 - categorical_accuracy: 0.7174
# Epoch 161/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6627 - categorical_accuracy: 0.7174
# Epoch 162/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6439 - categorical_accuracy: 0.7391
# Epoch 163/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6807 - categorical_accuracy: 0.7198
# Epoch 164/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.5973 - categorical_accuracy: 0.7367
# Epoch 165/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6210 - categorical_accuracy: 0.7198
# Epoch 166/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6230 - categorical_accuracy: 0.7440
# Epoch 167/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.5715 - categorical_accuracy: 0.7415
# Epoch 168/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6500 - categorical_accuracy: 0.7222
# Epoch 169/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6499 - categorical_accuracy: 0.7246
# Epoch 170/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6513 - categorical_accuracy: 0.7319
# Epoch 171/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5949 - categorical_accuracy: 0.7440
# Epoch 172/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6103 - categorical_accuracy: 0.7488
# Epoch 173/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6192 - categorical_accuracy: 0.7343
# Epoch 174/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.6089 - categorical_accuracy: 0.7246
# Epoch 175/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6443 - categorical_accuracy: 0.7367
# Epoch 176/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5786 - categorical_accuracy: 0.7415
# Epoch 177/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5998 - categorical_accuracy: 0.7536
# Epoch 178/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6440 - categorical_accuracy: 0.7343
# Epoch 179/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7356 - categorical_accuracy: 0.7126
# Epoch 180/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5569 - categorical_accuracy: 0.7633
# Epoch 181/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6320 - categorical_accuracy: 0.7585
# Epoch 182/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6685 - categorical_accuracy: 0.7319
# Epoch 183/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.7059 - categorical_accuracy: 0.6981
# Epoch 184/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6611 - categorical_accuracy: 0.7343
# Epoch 185/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5647 - categorical_accuracy: 0.7319
# Epoch 186/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6077 - categorical_accuracy: 0.7415
# Epoch 187/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6643 - categorical_accuracy: 0.7343
# Epoch 188/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5771 - categorical_accuracy: 0.7391
# Epoch 189/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6277 - categorical_accuracy: 0.7681
# Epoch 190/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6170 - categorical_accuracy: 0.7319
# Epoch 191/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6228 - categorical_accuracy: 0.7295
# Epoch 192/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6090 - categorical_accuracy: 0.7488
# Epoch 193/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6153 - categorical_accuracy: 0.7174
# Epoch 194/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7071 - categorical_accuracy: 0.6957
# Epoch 195/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6405 - categorical_accuracy: 0.7319
# Epoch 196/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6773 - categorical_accuracy: 0.7246
# Epoch 197/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6275 - categorical_accuracy: 0.7367
# Epoch 198/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6816 - categorical_accuracy: 0.7150
# Epoch 199/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5971 - categorical_accuracy: 0.7343
# Epoch 200/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6467 - categorical_accuracy: 0.7415
# Epoch 201/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6967 - categorical_accuracy: 0.6981
# Epoch 202/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5976 - categorical_accuracy: 0.7488
# Epoch 203/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7065 - categorical_accuracy: 0.6981
# Epoch 204/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6062 - categorical_accuracy: 0.7512
# Epoch 205/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7277 - categorical_accuracy: 0.6957
# Epoch 206/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6314 - categorical_accuracy: 0.7246
# Epoch 207/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6020 - categorical_accuracy: 0.7585
# Epoch 208/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6157 - categorical_accuracy: 0.7391
# Epoch 209/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.5813 - categorical_accuracy: 0.7440
# Epoch 210/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7136 - categorical_accuracy: 0.7005
# Epoch 211/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5943 - categorical_accuracy: 0.7415
# Epoch 212/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6363 - categorical_accuracy: 0.7488
# Epoch 213/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6294 - categorical_accuracy: 0.7246
# Epoch 214/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6281 - categorical_accuracy: 0.7536
# Epoch 215/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5626 - categorical_accuracy: 0.7633
# Epoch 216/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6000 - categorical_accuracy: 0.7440
# Epoch 217/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6038 - categorical_accuracy: 0.7246
# Epoch 218/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6245 - categorical_accuracy: 0.7295
# Epoch 219/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5960 - categorical_accuracy: 0.7464
# Epoch 220/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6505 - categorical_accuracy: 0.7295
# Epoch 221/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6860 - categorical_accuracy: 0.7077
# Epoch 222/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6641 - categorical_accuracy: 0.7101
# Epoch 223/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5682 - categorical_accuracy: 0.7802
# Epoch 224/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7186 - categorical_accuracy: 0.7101
# Epoch 225/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6225 - categorical_accuracy: 0.7536
# Epoch 226/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6035 - categorical_accuracy: 0.7391
# Epoch 227/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5942 - categorical_accuracy: 0.7560
# Epoch 228/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6305 - categorical_accuracy: 0.7174
# Epoch 229/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6711 - categorical_accuracy: 0.7077
# Epoch 230/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7624 - categorical_accuracy: 0.6594
# Epoch 231/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6290 - categorical_accuracy: 0.7077
# Epoch 232/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6376 - categorical_accuracy: 0.7343
# Epoch 233/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6492 - categorical_accuracy: 0.7415
# Epoch 234/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.7018 - categorical_accuracy: 0.7029
# Epoch 235/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6057 - categorical_accuracy: 0.7222
# Epoch 236/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6424 - categorical_accuracy: 0.7367
# Epoch 237/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6647 - categorical_accuracy: 0.7222
# Epoch 238/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6322 - categorical_accuracy: 0.7271
# Epoch 239/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6005 - categorical_accuracy: 0.7512
# Epoch 240/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6549 - categorical_accuracy: 0.7415
# Epoch 241/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.7008 - categorical_accuracy: 0.6932
# Epoch 242/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6237 - categorical_accuracy: 0.7440
# Epoch 243/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6630 - categorical_accuracy: 0.7198
# Epoch 244/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6199 - categorical_accuracy: 0.7464
# Epoch 245/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5374 - categorical_accuracy: 0.7657
# Epoch 246/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7079 - categorical_accuracy: 0.7198
# Epoch 247/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6174 - categorical_accuracy: 0.7295
# Epoch 248/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6202 - categorical_accuracy: 0.7440
# Epoch 249/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6396 - categorical_accuracy: 0.7633
# Epoch 250/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5900 - categorical_accuracy: 0.7560
# Epoch 251/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6303 - categorical_accuracy: 0.7440
# Epoch 252/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.5395 - categorical_accuracy: 0.7971
# Epoch 253/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6231 - categorical_accuracy: 0.7415
# Epoch 254/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6340 - categorical_accuracy: 0.7343
# Epoch 255/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6076 - categorical_accuracy: 0.7367
# Epoch 256/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6329 - categorical_accuracy: 0.7633
# Epoch 257/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7183 - categorical_accuracy: 0.7222
# Epoch 258/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6027 - categorical_accuracy: 0.7440
# Epoch 259/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5226 - categorical_accuracy: 0.7850
# Epoch 260/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5792 - categorical_accuracy: 0.7512
# Epoch 261/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6339 - categorical_accuracy: 0.7319
# Epoch 262/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6421 - categorical_accuracy: 0.7415
# Epoch 263/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6181 - categorical_accuracy: 0.7512
# Epoch 264/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5908 - categorical_accuracy: 0.7440
# Epoch 265/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5725 - categorical_accuracy: 0.7657
# Epoch 266/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6869 - categorical_accuracy: 0.7174
# Epoch 267/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6722 - categorical_accuracy: 0.7343
# Epoch 268/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5737 - categorical_accuracy: 0.7391
# Epoch 269/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6812 - categorical_accuracy: 0.6981
# Epoch 270/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6034 - categorical_accuracy: 0.7246
# Epoch 271/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5318 - categorical_accuracy: 0.7633
# Epoch 272/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6410 - categorical_accuracy: 0.7705
# Epoch 273/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6430 - categorical_accuracy: 0.7150
# Epoch 274/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6493 - categorical_accuracy: 0.7005
# Epoch 275/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6691 - categorical_accuracy: 0.7029
# Epoch 276/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6477 - categorical_accuracy: 0.7488
# Epoch 277/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6162 - categorical_accuracy: 0.7319
# Epoch 278/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6612 - categorical_accuracy: 0.7246
# Epoch 279/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6634 - categorical_accuracy: 0.7246
# Epoch 280/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6881 - categorical_accuracy: 0.7150
# Epoch 281/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6133 - categorical_accuracy: 0.7415
# Epoch 282/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6148 - categorical_accuracy: 0.7488
# Epoch 283/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6656 - categorical_accuracy: 0.6957
# Epoch 284/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6991 - categorical_accuracy: 0.7101
# Epoch 285/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6584 - categorical_accuracy: 0.7391
# Epoch 286/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5761 - categorical_accuracy: 0.7560
# Epoch 287/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6282 - categorical_accuracy: 0.7488
# Epoch 288/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6822 - categorical_accuracy: 0.7174
# Epoch 289/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6400 - categorical_accuracy: 0.7367
# Epoch 290/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6389 - categorical_accuracy: 0.7319
# Epoch 291/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6241 - categorical_accuracy: 0.7391
# Epoch 292/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6885 - categorical_accuracy: 0.7077
# Epoch 293/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6271 - categorical_accuracy: 0.7633
# Epoch 294/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6148 - categorical_accuracy: 0.7343
# Epoch 295/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6033 - categorical_accuracy: 0.7560
# Epoch 296/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5896 - categorical_accuracy: 0.7512
# Epoch 297/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6604 - categorical_accuracy: 0.7319
# Epoch 298/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5671 - categorical_accuracy: 0.7488
# Epoch 299/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6328 - categorical_accuracy: 0.7246
# Epoch 300/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6115 - categorical_accuracy: 0.7367
# Epoch 301/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6906 - categorical_accuracy: 0.7246
# Epoch 302/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6038 - categorical_accuracy: 0.7295
# Epoch 303/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6273 - categorical_accuracy: 0.7415
# Epoch 304/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6611 - categorical_accuracy: 0.6908
# Epoch 305/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6521 - categorical_accuracy: 0.7222
# Epoch 306/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6164 - categorical_accuracy: 0.7391
# Epoch 307/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6105 - categorical_accuracy: 0.7681
# Epoch 308/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6710 - categorical_accuracy: 0.7367
# Epoch 309/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6104 - categorical_accuracy: 0.7464
# Epoch 310/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6177 - categorical_accuracy: 0.7560
# Epoch 311/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6530 - categorical_accuracy: 0.7246
# Epoch 312/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6158 - categorical_accuracy: 0.7536
# Epoch 313/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5484 - categorical_accuracy: 0.7512
# Epoch 314/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6190 - categorical_accuracy: 0.7150
# Epoch 315/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6108 - categorical_accuracy: 0.7174
# Epoch 316/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6842 - categorical_accuracy: 0.6981
# Epoch 317/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5186 - categorical_accuracy: 0.7850
# Epoch 318/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6679 - categorical_accuracy: 0.7029
# Epoch 319/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6362 - categorical_accuracy: 0.7609
# Epoch 320/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7282 - categorical_accuracy: 0.7077
# Epoch 321/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6287 - categorical_accuracy: 0.7440
# Epoch 322/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6073 - categorical_accuracy: 0.7343
# Epoch 323/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6444 - categorical_accuracy: 0.7246
# Epoch 324/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6305 - categorical_accuracy: 0.7560
# Epoch 325/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6768 - categorical_accuracy: 0.7029
# Epoch 326/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6765 - categorical_accuracy: 0.7343
# Epoch 327/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5672 - categorical_accuracy: 0.7681
# Epoch 328/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5848 - categorical_accuracy: 0.7488
# Epoch 329/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5697 - categorical_accuracy: 0.7585
# Epoch 330/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6332 - categorical_accuracy: 0.7343
# Epoch 331/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6235 - categorical_accuracy: 0.7440
# Epoch 332/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7070 - categorical_accuracy: 0.6957
# Epoch 333/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5763 - categorical_accuracy: 0.7633
# Epoch 334/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6850 - categorical_accuracy: 0.7126
# Epoch 335/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6024 - categorical_accuracy: 0.7440
# Epoch 336/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6043 - categorical_accuracy: 0.7633
# Epoch 337/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5887 - categorical_accuracy: 0.7633
# Epoch 338/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.6236 - categorical_accuracy: 0.7174
# Epoch 339/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5938 - categorical_accuracy: 0.7512
# Epoch 340/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5510 - categorical_accuracy: 0.7633
# Epoch 341/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5893 - categorical_accuracy: 0.7464
# Epoch 342/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6502 - categorical_accuracy: 0.7174
# Epoch 343/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6270 - categorical_accuracy: 0.7295
# Epoch 344/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5723 - categorical_accuracy: 0.7536
# Epoch 345/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7228 - categorical_accuracy: 0.6860
# Epoch 346/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6209 - categorical_accuracy: 0.7343
# Epoch 347/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6673 - categorical_accuracy: 0.6981
# Epoch 348/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.6836 - categorical_accuracy: 0.7295
# Epoch 349/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6486 - categorical_accuracy: 0.7391
# Epoch 350/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5835 - categorical_accuracy: 0.7585
# Epoch 351/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6049 - categorical_accuracy: 0.7633
# Epoch 352/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5892 - categorical_accuracy: 0.7657
# Epoch 353/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6936 - categorical_accuracy: 0.7005
# Epoch 354/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6587 - categorical_accuracy: 0.7367
# Epoch 355/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6234 - categorical_accuracy: 0.7488
# Epoch 356/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7015 - categorical_accuracy: 0.6836
# Epoch 357/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6382 - categorical_accuracy: 0.7150
# Epoch 358/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6733 - categorical_accuracy: 0.7198
# Epoch 359/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6103 - categorical_accuracy: 0.7174
# Epoch 360/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7007 - categorical_accuracy: 0.7101
# Epoch 361/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6231 - categorical_accuracy: 0.7560
# Epoch 362/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6474 - categorical_accuracy: 0.7271
# Epoch 363/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6402 - categorical_accuracy: 0.7343
# Epoch 364/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6603 - categorical_accuracy: 0.7271
# Epoch 365/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5704 - categorical_accuracy: 0.7633
# Epoch 366/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5680 - categorical_accuracy: 0.7705
# Epoch 367/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6265 - categorical_accuracy: 0.7343
# Epoch 368/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5459 - categorical_accuracy: 0.7729
# Epoch 369/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6317 - categorical_accuracy: 0.7271
# Epoch 370/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6089 - categorical_accuracy: 0.7367
# Epoch 371/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6754 - categorical_accuracy: 0.7174
# Epoch 372/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6264 - categorical_accuracy: 0.7246
# Epoch 373/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6476 - categorical_accuracy: 0.7295
# Epoch 374/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.6785 - categorical_accuracy: 0.7150
# Epoch 375/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6159 - categorical_accuracy: 0.7391
# Epoch 376/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5555 - categorical_accuracy: 0.7488
# Epoch 377/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5964 - categorical_accuracy: 0.7536
# Epoch 378/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6054 - categorical_accuracy: 0.7343
# Epoch 379/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.5552 - categorical_accuracy: 0.7440
# Epoch 380/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5810 - categorical_accuracy: 0.7536
# Epoch 381/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6388 - categorical_accuracy: 0.7126
# Epoch 382/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5707 - categorical_accuracy: 0.7633
# Epoch 383/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5886 - categorical_accuracy: 0.7633
# Epoch 384/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6613 - categorical_accuracy: 0.7126
# Epoch 385/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6350 - categorical_accuracy: 0.7319
# Epoch 386/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5769 - categorical_accuracy: 0.7633
# Epoch 387/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7013 - categorical_accuracy: 0.7222
# Epoch 388/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6830 - categorical_accuracy: 0.7222
# Epoch 389/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6910 - categorical_accuracy: 0.6860
# Epoch 390/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5691 - categorical_accuracy: 0.7657
# Epoch 391/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6259 - categorical_accuracy: 0.7391
# Epoch 392/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6388 - categorical_accuracy: 0.7391
# Epoch 393/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6599 - categorical_accuracy: 0.7198
# Epoch 394/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6741 - categorical_accuracy: 0.6957
# Epoch 395/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7641 - categorical_accuracy: 0.6836
# Epoch 396/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.7138 - categorical_accuracy: 0.6812
# Epoch 397/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7215 - categorical_accuracy: 0.7005
# Epoch 398/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6953 - categorical_accuracy: 0.7101
# Epoch 399/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5841 - categorical_accuracy: 0.7560
# Epoch 400/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6027 - categorical_accuracy: 0.7391
# Epoch 401/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.7317 - categorical_accuracy: 0.6860
# Epoch 402/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6102 - categorical_accuracy: 0.7343
# Epoch 403/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6279 - categorical_accuracy: 0.7512
# Epoch 404/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.6208 - categorical_accuracy: 0.7585
# Epoch 405/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5429 - categorical_accuracy: 0.7585
# Epoch 406/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6978 - categorical_accuracy: 0.7077
# Epoch 407/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6762 - categorical_accuracy: 0.7150
# Epoch 408/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5868 - categorical_accuracy: 0.7585
# ...
# Epoch 439/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6419 - categorical_accuracy: 0.7271
# Epoch 440/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.6424 - categorical_accuracy: 0.7488
# Epoch 441/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5664 - categorical_accuracy: 0.7754
# Epoch 442/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.6265 - categorical_accuracy: 0.7415
# Epoch 443/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7079 - categorical_accuracy: 0.7077
# Epoch 444/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6097 - categorical_accuracy: 0.7415
# Epoch 445/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5808 - categorical_accuracy: 0.7295
# Epoch 446/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6588 - categorical_accuracy: 0.7367
# Epoch 447/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.5689 - categorical_accuracy: 0.7826
# Epoch 448/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6204 - categorical_accuracy: 0.7464
# Epoch 449/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6318 - categorical_accuracy: 0.7391
# Epoch 450/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6500 - categorical_accuracy: 0.7222
# Epoch 451/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6579 - categorical_accuracy: 0.7101
# Epoch 452/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6820 - categorical_accuracy: 0.7053
# Epoch 453/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6902 - categorical_accuracy: 0.7150
# Epoch 454/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6155 - categorical_accuracy: 0.7633
# Epoch 455/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5720 - categorical_accuracy: 0.7415
# Epoch 456/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6235 - categorical_accuracy: 0.7488
# Epoch 457/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6233 - categorical_accuracy: 0.7536
# Epoch 458/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6691 - categorical_accuracy: 0.7295
# Epoch 459/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6733 - categorical_accuracy: 0.7126
# Epoch 460/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6512 - categorical_accuracy: 0.7029
# Epoch 461/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6901 - categorical_accuracy: 0.7005
# Epoch 462/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6164 - categorical_accuracy: 0.7585
# Epoch 463/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6259 - categorical_accuracy: 0.7222
# Epoch 464/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6229 - categorical_accuracy: 0.7246
# Epoch 465/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6483 - categorical_accuracy: 0.7271
# Epoch 466/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.5826 - categorical_accuracy: 0.7633
# Epoch 467/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6495 - categorical_accuracy: 0.7174
# Epoch 468/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6330 - categorical_accuracy: 0.7464
# Epoch 469/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6247 - categorical_accuracy: 0.7271
# Epoch 470/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6149 - categorical_accuracy: 0.7415
# Epoch 471/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6321 - categorical_accuracy: 0.7367
# Epoch 472/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6088 - categorical_accuracy: 0.7174
# Epoch 473/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5722 - categorical_accuracy: 0.7585
# Epoch 474/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6525 - categorical_accuracy: 0.7150
# Epoch 475/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6197 - categorical_accuracy: 0.7512
# Epoch 476/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5877 - categorical_accuracy: 0.7536
# Epoch 477/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6533 - categorical_accuracy: 0.7101
# Epoch 478/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6301 - categorical_accuracy: 0.7415
# Epoch 479/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6094 - categorical_accuracy: 0.7295
# Epoch 480/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.6716 - categorical_accuracy: 0.7415
# Epoch 481/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6830 - categorical_accuracy: 0.7343
# Epoch 482/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6144 - categorical_accuracy: 0.7367
# Epoch 483/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6681 - categorical_accuracy: 0.7246
# Epoch 484/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7179 - categorical_accuracy: 0.6932
# Epoch 485/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6362 - categorical_accuracy: 0.7319
# Epoch 486/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6183 - categorical_accuracy: 0.7536
# Epoch 487/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6394 - categorical_accuracy: 0.7198
# Epoch 488/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6528 - categorical_accuracy: 0.7343
# Epoch 489/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6285 - categorical_accuracy: 0.7271
# Epoch 490/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7104 - categorical_accuracy: 0.7174
# Epoch 491/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5896 - categorical_accuracy: 0.7536
# Epoch 492/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6702 - categorical_accuracy: 0.7271
# Epoch 493/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5887 - categorical_accuracy: 0.7512
# Epoch 494/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5847 - categorical_accuracy: 0.7705
# Epoch 495/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5876 - categorical_accuracy: 0.7440
# Epoch 496/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6785 - categorical_accuracy: 0.7198
# Epoch 497/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6304 - categorical_accuracy: 0.7295
# Epoch 498/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6015 - categorical_accuracy: 0.7585
# Epoch 499/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.5774 - categorical_accuracy: 0.7609
# Epoch 500/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7313 - categorical_accuracy: 0.6836
# Epoch 501/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6075 - categorical_accuracy: 0.7464
# Epoch 502/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6441 - categorical_accuracy: 0.7440
# Epoch 503/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6895 - categorical_accuracy: 0.7126
# Epoch 504/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6454 - categorical_accuracy: 0.7174
# Epoch 505/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6500 - categorical_accuracy: 0.7150
# Epoch 506/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6496 - categorical_accuracy: 0.7053
# Epoch 507/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6179 - categorical_accuracy: 0.7295
# Epoch 508/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6429 - categorical_accuracy: 0.7440
# Epoch 509/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6817 - categorical_accuracy: 0.7005
# Epoch 510/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6560 - categorical_accuracy: 0.7053
# Epoch 511/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5842 - categorical_accuracy: 0.7391
# Epoch 512/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.5317 - categorical_accuracy: 0.7729
# Epoch 513/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6423 - categorical_accuracy: 0.7464
# Epoch 514/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6097 - categorical_accuracy: 0.7464
# Epoch 515/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6478 - categorical_accuracy: 0.7391
# Epoch 516/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7129 - categorical_accuracy: 0.7415
# Epoch 517/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6376 - categorical_accuracy: 0.7198
# Epoch 518/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6591 - categorical_accuracy: 0.7415
# Epoch 519/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6508 - categorical_accuracy: 0.7536
# Epoch 520/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6423 - categorical_accuracy: 0.7488
# Epoch 521/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.7230 - categorical_accuracy: 0.7150
# Epoch 522/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5955 - categorical_accuracy: 0.7512
# Epoch 523/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6816 - categorical_accuracy: 0.7343
# Epoch 524/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6673 - categorical_accuracy: 0.7150
# Epoch 525/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7219 - categorical_accuracy: 0.7101
# Epoch 526/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.6410 - categorical_accuracy: 0.7367
# Epoch 527/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6841 - categorical_accuracy: 0.7198
# Epoch 528/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6275 - categorical_accuracy: 0.7512
# Epoch 529/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6843 - categorical_accuracy: 0.7222
# Epoch 530/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6561 - categorical_accuracy: 0.7295
# Epoch 531/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6020 - categorical_accuracy: 0.7464
# Epoch 532/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6730 - categorical_accuracy: 0.7319
# Epoch 533/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.6466 - categorical_accuracy: 0.7174
# Epoch 534/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5949 - categorical_accuracy: 0.7367
# Epoch 535/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6067 - categorical_accuracy: 0.7536
# Epoch 536/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6861 - categorical_accuracy: 0.7101
# Epoch 537/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5817 - categorical_accuracy: 0.7802
# Epoch 538/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7074 - categorical_accuracy: 0.6981
# Epoch 539/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5558 - categorical_accuracy: 0.7705
# Epoch 540/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6187 - categorical_accuracy: 0.7464
# Epoch 541/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6370 - categorical_accuracy: 0.7440
# Epoch 542/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6296 - categorical_accuracy: 0.7295
# Epoch 543/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6768 - categorical_accuracy: 0.7343
# Epoch 544/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6909 - categorical_accuracy: 0.7077
# Epoch 545/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6805 - categorical_accuracy: 0.7198
# Epoch 546/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6193 - categorical_accuracy: 0.7367
# Epoch 547/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5686 - categorical_accuracy: 0.7778
# Epoch 548/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6410 - categorical_accuracy: 0.7222
# Epoch 549/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5839 - categorical_accuracy: 0.7560
# Epoch 550/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5754 - categorical_accuracy: 0.7729
# Epoch 551/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7247 - categorical_accuracy: 0.7150
# Epoch 552/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6138 - categorical_accuracy: 0.7415
# Epoch 553/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.7453 - categorical_accuracy: 0.6812
# Epoch 554/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6890 - categorical_accuracy: 0.7391
# Epoch 555/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6644 - categorical_accuracy: 0.7295
# Epoch 556/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6026 - categorical_accuracy: 0.7464
# Epoch 557/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6301 - categorical_accuracy: 0.7367
# Epoch 558/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6281 - categorical_accuracy: 0.7198
# Epoch 559/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5973 - categorical_accuracy: 0.7560
# Epoch 560/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6374 - categorical_accuracy: 0.7271
# Epoch 561/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6555 - categorical_accuracy: 0.7246
# Epoch 562/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5467 - categorical_accuracy: 0.7681
# Epoch 563/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6601 - categorical_accuracy: 0.7367
# Epoch 564/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6692 - categorical_accuracy: 0.7391
# Epoch 565/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6609 - categorical_accuracy: 0.7222
# Epoch 566/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.7330 - categorical_accuracy: 0.7029
# Epoch 567/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.5938 - categorical_accuracy: 0.7585
# Epoch 568/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6296 - categorical_accuracy: 0.7198
# Epoch 569/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6974 - categorical_accuracy: 0.6884
# Epoch 570/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6192 - categorical_accuracy: 0.7367
# Epoch 571/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6257 - categorical_accuracy: 0.7198
# Epoch 572/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.6691 - categorical_accuracy: 0.7246
# Epoch 573/1000
# 104/104 [==============================] - 147s 1s/step - loss: 0.6286 - categorical_accuracy: 0.7319
# Epoch 574/1000
#  49/104 [=============>................] - ETA: 1:17 - loss: 0.6333 - categorical_accuracy: 0.7551
