# %%
import os
import cv2
import numpy as np
from glob import glob
from tqdm import tqdm
import matplotlib.pyplot as plt
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Lambda, Dense, Dropout, Conv2D, MaxPooling2D, Flatten,Activation,BatchNormalization
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.losses import CategoricalCrossentropy

from tensorflow.keras import callbacks as cb
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from sklearn.model_selection import train_test_split

gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth( device=gpu, enable=True)

# %%
all_classes = glob('/home/jovyan/data/fungi/images/*')
source_classes,target_classes=train_test_split(all_classes,test_size=0.1)
sorce_len=len(source_classes)
target_len=len(target_classes)
print(f"total {len(all_classes)} classes=source {sorce_len} + target {target_len} classes")
# Out:
# total 1394 classes=source 1254 + target 140 classes

# %%
W,H,CH = 224,224,3
# W,H,CH = 64,64,3
def load_img(path, width = W):
    img = tf.io.read_file(path)
    img = tf.image.decode_jpeg(img, channels=CH)/255
    img = img.numpy()
    
    shape_dst = np.min(img.shape[:2])
    oh = (img.shape[0] - shape_dst) // 2
    ow = (img.shape[1] - shape_dst) // 2
    center_square = np.array([width,width])// 2
    new_size=(width,width)
    
    # cropping + resize
    img = img[oh:oh + shape_dst, ow:ow + shape_dst]
    img=cv2.resize(img, new_size)
    
    # Random affine+rotation
#     random_state = np.random.RandomState(seed=None)
#     alpha_affine=img.shape[0] * 0.1
#     pts1 = np.float32([center_square + width, 
#                        [center_square[0]+width, center_square[1]-width],
#                        center_square - width])
#     pts2 = pts1 + random_state.uniform(-alpha_affine, alpha_affine, size=pts1.shape).astype(np.float32)
#     M = cv2.getAffineTransform(pts1, pts2)
#     rot_mat = cv2.getRotationMatrix2D(tuple(center_square),random_state.rand()*360., 1.0)
#     img = cv2.warpAffine(img, M, new_size, borderMode=cv2.BORDER_REPLICATE)
#     img = cv2.warpAffine(img, rot_mat, new_size, borderMode=cv2.BORDER_REPLICATE)
    return tf.constant(img)

# %%
WAYS = 3
SHOTS=5
QUERIES=1
BATCH_SIZE=4

# %%
min([len(glob(sdir+'/*.JPG')) for sdir in source_classes])
# Out:
# 6

# %%
## exclude classes with too few examples
source_classes=[sdir for sdir in source_classes if len(glob(sdir+'/*.JPG'))>SHOTS+QUERIES]

sorce_len=len(source_classes)
print(f"source {sorce_len} + target {target_len} classes")
# Out:
# source 1242 + target 140 classes

# %%
min([len(glob(sdir+'/*.JPG')) for sdir in source_classes])
# Out:
# 7

# %%
map_fun=lambda string: tf.py_function(func=load_img,inp=[string], Tout=tf.float32)
all_sub = [
    tf.data.Dataset.list_files(sc+'/*.JPG', shuffle=True)
    .map(map_fun)
    for sc in source_classes
]

def gen():
    supports = []
    querys = []
    order=np.random.permutation(len(all_sub))
    for tasks in range(len(all_sub)//WAYS):
        picked=[all_sub[tt] for tt in order[WAYS*tasks:WAYS*(tasks+1)]]
        support = tf.concat(
            [
                next(
                    iter(
                        sub.batch(SHOTS).prefetch(SHOTS)
                    )
                    ) for sub in picked
            ]
            , axis=0)
        idxs=np.random.choice(range(WAYS), size=QUERIES, replace=False)
        query = tf.concat(
            [
                next(
                    iter(
                        picked[idx].batch(1).prefetch(1)
                    )
                    ) for idx in idxs
            ]
            , axis=0)
        yield tf.concat([support, query], axis=0), tuple([keras.utils.to_categorical(idx,num_classes=WAYS) for idx in idxs])
dd = tf.data.Dataset.from_generator(gen,
                                    output_types=(tf.float32,tuple([tf.float32]*QUERIES)),
                                    output_shapes=((WAYS*SHOTS+QUERIES,W,H,CH),tuple([WAYS]*QUERIES))
                                   ).batch(BATCH_SIZE)

# %%
# %%time
aa=next(iter(dd))
# Out:
# CPU times: user 941 ms, sys: 349 ms, total: 1.29 s
# Wall time: 1.01 s

# %%
def build_base_network(input_shape):
    
    seq = Sequential()
    kernel_size = 3
    #convolutional layer 1
    seq.add(Conv2D(64, kernel_size=3, input_shape=input_shape,
                           padding="valid",activation='relu'))
    seq.add(BatchNormalization()) 
    seq.add(MaxPooling2D(pool_size=(2, 2)))  
    seq.add(Dropout(.25))
    
    #convolutional layer 2
    seq.add(Conv2D(64, kernel_size=3, padding="valid",activation='relu'))
    seq.add(BatchNormalization()) 
    seq.add(MaxPooling2D(pool_size=(2, 2))) 
    seq.add(Dropout(.25))

    #convolutional layer 3
    seq.add(Conv2D(64, kernel_size=3, padding="valid",activation='relu'))
    seq.add(BatchNormalization()) 
    seq.add(Dropout(.25))
    return seq
def build_relation_network(input_shape):
    seq = Sequential()
    #layer1
    seq.add(Conv2D(64, kernel_size=3, input_shape=input_shape,
                           padding="valid",activation='relu'))
    seq.add(BatchNormalization()) 
    seq.add(MaxPooling2D(pool_size=(2, 2)))  
    seq.add(Dropout(.25))
    
    seq.add(Flatten())
    seq.add(Dense(16, activation='relu'))
    seq.add(Dropout(0.1))
    seq.add(Dense(1, activation=None))
    return seq

# %%
base_dim = (W,H,CH)
base_network = build_base_network(base_dim)
# Query feature
x_in=Input(shape=(WAYS*SHOTS+QUERIES,W,H,CH))
latent_s=[base_network(x_in[:,ii]) for ii in range(WAYS*SHOTS)]
latent_q=[base_network(x_in[:,WAYS*SHOTS+ii]) for ii in range(QUERIES)]
relation_net=build_relation_network((latent_q[0].shape[-3],latent_q[0].shape[-2],latent_q[0].shape[-1]*2))
y=list()
for qq in range(QUERIES):
    relation_scores=list()
    for ww in range(WAYS):
        mean_latent=tf.reduce_mean(tf.stack(latent_s[ww*SHOTS:ww*SHOTS+SHOTS],axis=-1),axis=-1)
        relation=relation_net(tf.concat((mean_latent,latent_q[qq]),axis=-1))
        relation_scores.append(relation)
    y.append(tf.nn.softmax(tf.concat(relation_scores,axis=-1)))

model = Model(inputs=x_in, outputs=tuple(y))

# %%
lr=0.001
def scheduler(epoch):
    global lr
    if epoch % 3 == 0:
        lr /= 2
    return lr
reduce_lr = cb.ReduceLROnPlateau(monitor='loss', factor=0.4,patience=2, min_lr=1e-8)
lr_sched = cb.LearningRateScheduler(scheduler)
tensorboard = cb.TensorBoard()
opt = tf.keras.optimizers.Adam(lr=lr)
model.compile(loss=CategoricalCrossentropy(), optimizer=opt, metrics=['categorical_accuracy'])

# %%
# %%time
model.fit(dd, epochs=1000, verbose=1,workers=4, callbacks=[reduce_lr,lr_sched, tensorboard])
# Out:
# Epoch 1/1000
# 104/104 [==============================] - 103s 993ms/step - loss: 1.2717 - categorical_accuracy: 0.2874
# Epoch 2/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0986 - categorical_accuracy: 0.3333
# Epoch 3/1000
# 104/104 [==============================] - 102s 983ms/step - loss: 1.1041 - categorical_accuracy: 0.3068
# Epoch 4/1000
# 104/104 [==============================] - 102s 983ms/step - loss: 1.1347 - categorical_accuracy: 0.3140
# Epoch 5/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0995 - categorical_accuracy: 0.3164
# Epoch 6/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0983 - categorical_accuracy: 0.3696
# Epoch 7/1000
# 104/104 [==============================] - 102s 983ms/step - loss: 1.0976 - categorical_accuracy: 0.3140
# Epoch 8/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0983 - categorical_accuracy: 0.3671
# Epoch 9/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0979 - categorical_accuracy: 0.3237
# Epoch 10/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0982 - categorical_accuracy: 0.3889
# Epoch 11/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0974 - categorical_accuracy: 0.3478
# Epoch 12/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0983 - categorical_accuracy: 0.3744
# Epoch 13/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0975 - categorical_accuracy: 0.3527
# Epoch 14/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0948 - categorical_accuracy: 0.3599
# Epoch 15/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0919 - categorical_accuracy: 0.3551
# Epoch 16/1000
# 104/104 [==============================] - 102s 983ms/step - loss: 1.0967 - categorical_accuracy: 0.3575
# Epoch 17/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0936 - categorical_accuracy: 0.3575
# Epoch 18/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0913 - categorical_accuracy: 0.3986
# Epoch 19/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0971 - categorical_accuracy: 0.3188
# Epoch 20/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0965 - categorical_accuracy: 0.3237
# Epoch 21/1000
# 104/104 [==============================] - 101s 972ms/step - loss: 1.0922 - categorical_accuracy: 0.3720
# Epoch 22/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0932 - categorical_accuracy: 0.3671
# Epoch 23/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0959 - categorical_accuracy: 0.3551
# Epoch 24/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.1000 - categorical_accuracy: 0.3575
# Epoch 25/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0914 - categorical_accuracy: 0.3865
# Epoch 26/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0986 - categorical_accuracy: 0.3357
# Epoch 27/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0976 - categorical_accuracy: 0.3406
# Epoch 28/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0940 - categorical_accuracy: 0.3744
# Epoch 29/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0975 - categorical_accuracy: 0.3575
# Epoch 30/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0932 - categorical_accuracy: 0.3768
# Epoch 31/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0946 - categorical_accuracy: 0.3382
# Epoch 32/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0953 - categorical_accuracy: 0.3647
# Epoch 33/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0898 - categorical_accuracy: 0.3889
# Epoch 34/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0917 - categorical_accuracy: 0.3478
# Epoch 35/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0908 - categorical_accuracy: 0.3502
# Epoch 36/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0928 - categorical_accuracy: 0.3551
# Epoch 37/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0918 - categorical_accuracy: 0.3792
# Epoch 38/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0963 - categorical_accuracy: 0.3502
# Epoch 39/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.1011 - categorical_accuracy: 0.3213
# Epoch 40/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0872 - categorical_accuracy: 0.4082
# Epoch 41/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0866 - categorical_accuracy: 0.3792
# Epoch 42/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0926 - categorical_accuracy: 0.3889
# Epoch 43/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0960 - categorical_accuracy: 0.3551
# Epoch 44/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0973 - categorical_accuracy: 0.3333
# Epoch 45/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0947 - categorical_accuracy: 0.3551
# Epoch 46/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0953 - categorical_accuracy: 0.3285
# Epoch 47/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0904 - categorical_accuracy: 0.3720
# Epoch 48/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0952 - categorical_accuracy: 0.3502
# Epoch 49/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0929 - categorical_accuracy: 0.3575
# Epoch 50/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0944 - categorical_accuracy: 0.3744
# Epoch 51/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0920 - categorical_accuracy: 0.3889
# Epoch 52/1000
# 104/104 [==============================] - 102s 983ms/step - loss: 1.0966 - categorical_accuracy: 0.3768
# Epoch 53/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0940 - categorical_accuracy: 0.3575
# Epoch 54/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.1041 - categorical_accuracy: 0.3502
# Epoch 55/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0959 - categorical_accuracy: 0.3768
# Epoch 56/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0917 - categorical_accuracy: 0.4010
# Epoch 57/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0958 - categorical_accuracy: 0.3430
# Epoch 58/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0979 - categorical_accuracy: 0.3696
# Epoch 59/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0994 - categorical_accuracy: 0.3527
# Epoch 60/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0969 - categorical_accuracy: 0.3333
# Epoch 61/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0976 - categorical_accuracy: 0.3720
# Epoch 62/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0958 - categorical_accuracy: 0.3478
# Epoch 63/1000
# 104/104 [==============================] - 101s 973ms/step - loss: 1.0964 - categorical_accuracy: 0.3261
# Epoch 64/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0971 - categorical_accuracy: 0.3213
# Epoch 65/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0985 - categorical_accuracy: 0.3551
# Epoch 66/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0956 - categorical_accuracy: 0.3382
# Epoch 67/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0910 - categorical_accuracy: 0.3454
# Epoch 68/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0968 - categorical_accuracy: 0.3575
# Epoch 69/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0939 - categorical_accuracy: 0.3478
# Epoch 70/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0974 - categorical_accuracy: 0.3792
# Epoch 71/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0908 - categorical_accuracy: 0.3647
# Epoch 72/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0894 - categorical_accuracy: 0.3744
# Epoch 73/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0879 - categorical_accuracy: 0.3816
# Epoch 74/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0949 - categorical_accuracy: 0.3502
# Epoch 75/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0951 - categorical_accuracy: 0.3623
# Epoch 76/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0979 - categorical_accuracy: 0.3478
# Epoch 77/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0943 - categorical_accuracy: 0.3454
# Epoch 78/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0936 - categorical_accuracy: 0.3478
# Epoch 79/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.1003 - categorical_accuracy: 0.3188
# Epoch 80/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0960 - categorical_accuracy: 0.3792
# Epoch 81/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0966 - categorical_accuracy: 0.3527
# Epoch 82/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0945 - categorical_accuracy: 0.3599
# Epoch 83/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0904 - categorical_accuracy: 0.3841
# Epoch 84/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0964 - categorical_accuracy: 0.3478
# Epoch 85/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0952 - categorical_accuracy: 0.3671
# Epoch 86/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0983 - categorical_accuracy: 0.3575
# Epoch 87/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0910 - categorical_accuracy: 0.3816
# Epoch 88/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0974 - categorical_accuracy: 0.3237
# Epoch 89/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0929 - categorical_accuracy: 0.3430
# Epoch 90/1000
# 104/104 [==============================] - 101s 972ms/step - loss: 1.0958 - categorical_accuracy: 0.3333
# Epoch 91/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0979 - categorical_accuracy: 0.3720
# Epoch 92/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0955 - categorical_accuracy: 0.3720
# Epoch 93/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0996 - categorical_accuracy: 0.3140
# Epoch 94/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0943 - categorical_accuracy: 0.3865
# Epoch 95/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0942 - categorical_accuracy: 0.3720
# Epoch 96/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0958 - categorical_accuracy: 0.3865
# Epoch 97/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0982 - categorical_accuracy: 0.3623
# Epoch 98/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0931 - categorical_accuracy: 0.3382
# Epoch 99/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0955 - categorical_accuracy: 0.3309
# Epoch 100/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0922 - categorical_accuracy: 0.3599
# Epoch 101/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.1021 - categorical_accuracy: 0.3527
# Epoch 102/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0952 - categorical_accuracy: 0.3551
# Epoch 103/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0949 - categorical_accuracy: 0.3841
# Epoch 104/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0831 - categorical_accuracy: 0.3986
# Epoch 105/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0913 - categorical_accuracy: 0.3986
# Epoch 106/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0950 - categorical_accuracy: 0.3454
# Epoch 107/1000
# 104/104 [==============================] - 101s 973ms/step - loss: 1.0900 - categorical_accuracy: 0.3865
# Epoch 108/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0964 - categorical_accuracy: 0.3454
# Epoch 109/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0984 - categorical_accuracy: 0.3430
# Epoch 110/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0994 - categorical_accuracy: 0.3092
# Epoch 111/1000
# 104/104 [==============================] - 102s 983ms/step - loss: 1.0947 - categorical_accuracy: 0.3575
# Epoch 112/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0907 - categorical_accuracy: 0.3986
# Epoch 113/1000
# 104/104 [==============================] - 101s 973ms/step - loss: 1.0956 - categorical_accuracy: 0.3357
# Epoch 114/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0976 - categorical_accuracy: 0.3357
# Epoch 115/1000
# 104/104 [==============================] - 101s 973ms/step - loss: 1.0946 - categorical_accuracy: 0.3720
# Epoch 116/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.1013 - categorical_accuracy: 0.3647
# Epoch 117/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0931 - categorical_accuracy: 0.3599
# Epoch 118/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0954 - categorical_accuracy: 0.3478
# Epoch 119/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0892 - categorical_accuracy: 0.3865
# Epoch 120/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.1010 - categorical_accuracy: 0.3430
# Epoch 121/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0935 - categorical_accuracy: 0.3430
# Epoch 122/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0899 - categorical_accuracy: 0.4034
# Epoch 123/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0949 - categorical_accuracy: 0.3647
# Epoch 124/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0910 - categorical_accuracy: 0.3551
# Epoch 125/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0982 - categorical_accuracy: 0.3430
# Epoch 126/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0978 - categorical_accuracy: 0.3551
# Epoch 127/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0963 - categorical_accuracy: 0.3382
# Epoch 128/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0933 - categorical_accuracy: 0.3478
# Epoch 129/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0926 - categorical_accuracy: 0.3164
# Epoch 130/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0940 - categorical_accuracy: 0.3647
# Epoch 131/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0927 - categorical_accuracy: 0.3792
# Epoch 132/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0944 - categorical_accuracy: 0.3454
# Epoch 133/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0965 - categorical_accuracy: 0.3792
# Epoch 134/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0944 - categorical_accuracy: 0.3406
# Epoch 135/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0918 - categorical_accuracy: 0.3478
# Epoch 136/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0875 - categorical_accuracy: 0.4034
# Epoch 137/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0898 - categorical_accuracy: 0.3599
# Epoch 138/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0942 - categorical_accuracy: 0.3333
# Epoch 139/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0926 - categorical_accuracy: 0.3357
# Epoch 140/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0937 - categorical_accuracy: 0.3309
# Epoch 141/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.1009 - categorical_accuracy: 0.3382
# Epoch 142/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0929 - categorical_accuracy: 0.3599
# Epoch 143/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0941 - categorical_accuracy: 0.3937
# Epoch 144/1000
# 104/104 [==============================] - 101s 972ms/step - loss: 1.0964 - categorical_accuracy: 0.3599
# Epoch 145/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0877 - categorical_accuracy: 0.3792
# Epoch 146/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0956 - categorical_accuracy: 0.3333
# Epoch 147/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0953 - categorical_accuracy: 0.3237
# Epoch 148/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0955 - categorical_accuracy: 0.3188
# Epoch 149/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0861 - categorical_accuracy: 0.4010
# Epoch 150/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0884 - categorical_accuracy: 0.3671
# Epoch 151/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0953 - categorical_accuracy: 0.3647
# Epoch 152/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0921 - categorical_accuracy: 0.3285
# Epoch 153/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0995 - categorical_accuracy: 0.3502
# Epoch 154/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0973 - categorical_accuracy: 0.3744
# Epoch 155/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0957 - categorical_accuracy: 0.4034
# Epoch 156/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0926 - categorical_accuracy: 0.3647
# Epoch 157/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0955 - categorical_accuracy: 0.3406
# Epoch 158/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0876 - categorical_accuracy: 0.3913
# Epoch 159/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0877 - categorical_accuracy: 0.3961
# Epoch 160/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0961 - categorical_accuracy: 0.3164
# Epoch 161/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0921 - categorical_accuracy: 0.3913
# Epoch 162/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0959 - categorical_accuracy: 0.3937
# Epoch 163/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0975 - categorical_accuracy: 0.3744
# Epoch 164/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0990 - categorical_accuracy: 0.3188
# Epoch 165/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0946 - categorical_accuracy: 0.3430
# Epoch 166/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.1031 - categorical_accuracy: 0.2850
# Epoch 167/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0972 - categorical_accuracy: 0.3068
# Epoch 168/1000
# 104/104 [==============================] - 101s 973ms/step - loss: 1.0922 - categorical_accuracy: 0.3406
# Epoch 169/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0945 - categorical_accuracy: 0.3502
# Epoch 170/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.1006 - categorical_accuracy: 0.3647
# Epoch 171/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0939 - categorical_accuracy: 0.3261
# Epoch 172/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0922 - categorical_accuracy: 0.3792
# Epoch 173/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0932 - categorical_accuracy: 0.3671
# Epoch 174/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0945 - categorical_accuracy: 0.3623
# Epoch 175/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.1057 - categorical_accuracy: 0.3430
# Epoch 176/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0956 - categorical_accuracy: 0.3647
# Epoch 177/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0967 - categorical_accuracy: 0.3623
# Epoch 178/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0971 - categorical_accuracy: 0.3357
# Epoch 179/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0957 - categorical_accuracy: 0.3720
# Epoch 180/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0940 - categorical_accuracy: 0.4106
# Epoch 181/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0941 - categorical_accuracy: 0.3889
# Epoch 182/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0997 - categorical_accuracy: 0.3237
# Epoch 183/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0948 - categorical_accuracy: 0.3430
# Epoch 184/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0983 - categorical_accuracy: 0.3478
# Epoch 185/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0912 - categorical_accuracy: 0.3575
# Epoch 186/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.1003 - categorical_accuracy: 0.3357
# Epoch 187/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0993 - categorical_accuracy: 0.3140
# Epoch 188/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.1050 - categorical_accuracy: 0.3454
# Epoch 189/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0924 - categorical_accuracy: 0.3454
# Epoch 190/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0951 - categorical_accuracy: 0.3478
# Epoch 191/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0881 - categorical_accuracy: 0.3744
# Epoch 192/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0921 - categorical_accuracy: 0.3575
# Epoch 193/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.1035 - categorical_accuracy: 0.3502
# Epoch 194/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0960 - categorical_accuracy: 0.3309
# Epoch 195/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0998 - categorical_accuracy: 0.3068
# Epoch 196/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.1003 - categorical_accuracy: 0.3116
# Epoch 197/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0878 - categorical_accuracy: 0.3937
# Epoch 198/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0974 - categorical_accuracy: 0.3140
# Epoch 199/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0897 - categorical_accuracy: 0.3551
# Epoch 200/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0994 - categorical_accuracy: 0.3357
# Epoch 201/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0977 - categorical_accuracy: 0.3406
# Epoch 202/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0977 - categorical_accuracy: 0.3454
# Epoch 203/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0962 - categorical_accuracy: 0.3502
# Epoch 204/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.1047 - categorical_accuracy: 0.3309
# Epoch 205/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0919 - categorical_accuracy: 0.3647
# Epoch 206/1000
# 104/104 [==============================] - 101s 973ms/step - loss: 1.0982 - categorical_accuracy: 0.3382
# Epoch 207/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0921 - categorical_accuracy: 0.3865
# Epoch 208/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0888 - categorical_accuracy: 0.3816
# Epoch 209/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0969 - categorical_accuracy: 0.3792
# Epoch 210/1000
# 104/104 [==============================] - 101s 972ms/step - loss: 1.0990 - categorical_accuracy: 0.3261
# Epoch 211/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0946 - categorical_accuracy: 0.3720
# Epoch 212/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0920 - categorical_accuracy: 0.3792
# Epoch 213/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0983 - categorical_accuracy: 0.3599
# Epoch 214/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0925 - categorical_accuracy: 0.3816
# Epoch 215/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0968 - categorical_accuracy: 0.3261
# Epoch 216/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0970 - categorical_accuracy: 0.3575
# Epoch 217/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0900 - categorical_accuracy: 0.3575
# Epoch 218/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0923 - categorical_accuracy: 0.3285
# Epoch 219/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.1001 - categorical_accuracy: 0.3357
# Epoch 220/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0927 - categorical_accuracy: 0.3720
# Epoch 221/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0993 - categorical_accuracy: 0.3527
# Epoch 222/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0966 - categorical_accuracy: 0.3671
# Epoch 223/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0949 - categorical_accuracy: 0.3575
# Epoch 224/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0882 - categorical_accuracy: 0.3671
# Epoch 225/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0949 - categorical_accuracy: 0.3599
# Epoch 226/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0941 - categorical_accuracy: 0.3671
# Epoch 227/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0954 - categorical_accuracy: 0.3164
# Epoch 228/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.1007 - categorical_accuracy: 0.3478
# Epoch 229/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0920 - categorical_accuracy: 0.3309
# Epoch 230/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0968 - categorical_accuracy: 0.3164
# Epoch 231/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0875 - categorical_accuracy: 0.4010
# Epoch 232/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0984 - categorical_accuracy: 0.3309
# Epoch 233/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0962 - categorical_accuracy: 0.3406
# Epoch 234/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.1007 - categorical_accuracy: 0.3502
# Epoch 235/1000
# 104/104 [==============================] - 103s 989ms/step - loss: 1.0951 - categorical_accuracy: 0.3696
# Epoch 236/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0979 - categorical_accuracy: 0.3140
# Epoch 237/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0953 - categorical_accuracy: 0.3478
# Epoch 238/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0966 - categorical_accuracy: 0.3478
# Epoch 239/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0943 - categorical_accuracy: 0.3430
# Epoch 240/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0887 - categorical_accuracy: 0.3357
# Epoch 241/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0936 - categorical_accuracy: 0.3164
# Epoch 242/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0981 - categorical_accuracy: 0.3502
# Epoch 243/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0967 - categorical_accuracy: 0.3430
# Epoch 244/1000
# 104/104 [==============================] - 102s 984ms/step - loss: 1.0943 - categorical_accuracy: 0.3816
# Epoch 245/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0981 - categorical_accuracy: 0.3551
# Epoch 246/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0997 - categorical_accuracy: 0.3285
# Epoch 247/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0956 - categorical_accuracy: 0.3164
# Epoch 248/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.1006 - categorical_accuracy: 0.3816
# Epoch 249/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0878 - categorical_accuracy: 0.3551
# Epoch 250/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0963 - categorical_accuracy: 0.3792
# Epoch 251/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0917 - categorical_accuracy: 0.3986
# Epoch 252/1000
# 104/104 [==============================] - 101s 973ms/step - loss: 1.0922 - categorical_accuracy: 0.3671
# Epoch 253/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0935 - categorical_accuracy: 0.3671
# Epoch 254/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0930 - categorical_accuracy: 0.3357
# Epoch 255/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.1034 - categorical_accuracy: 0.3068
# Epoch 256/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0933 - categorical_accuracy: 0.3382
# Epoch 257/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0960 - categorical_accuracy: 0.3575
# Epoch 258/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0975 - categorical_accuracy: 0.3768
# Epoch 259/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.1000 - categorical_accuracy: 0.3430
# Epoch 260/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0945 - categorical_accuracy: 0.3575
# Epoch 261/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0947 - categorical_accuracy: 0.3671
# Epoch 262/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0915 - categorical_accuracy: 0.3261
# Epoch 263/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0942 - categorical_accuracy: 0.3454
# Epoch 264/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0900 - categorical_accuracy: 0.3720
# Epoch 265/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0944 - categorical_accuracy: 0.3744
# Epoch 266/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0921 - categorical_accuracy: 0.3865
# Epoch 267/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0947 - categorical_accuracy: 0.3696
# Epoch 268/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0895 - categorical_accuracy: 0.3768
# Epoch 269/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0960 - categorical_accuracy: 0.3454
# Epoch 270/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0917 - categorical_accuracy: 0.3937
# Epoch 271/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0972 - categorical_accuracy: 0.3285
# Epoch 272/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0964 - categorical_accuracy: 0.3551
# Epoch 273/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0937 - categorical_accuracy: 0.3647
# Epoch 274/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0966 - categorical_accuracy: 0.3527
# Epoch 275/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0951 - categorical_accuracy: 0.3696
# Epoch 276/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0968 - categorical_accuracy: 0.3454
# Epoch 277/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.1012 - categorical_accuracy: 0.3285
# Epoch 278/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0947 - categorical_accuracy: 0.3478
# Epoch 279/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0968 - categorical_accuracy: 0.3768
# Epoch 280/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0985 - categorical_accuracy: 0.3575
# Epoch 281/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0927 - categorical_accuracy: 0.3744
# Epoch 282/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0970 - categorical_accuracy: 0.3454
# Epoch 283/1000
# 104/104 [==============================] - 102s 983ms/step - loss: 1.0926 - categorical_accuracy: 0.3768
# Epoch 284/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0987 - categorical_accuracy: 0.3430
# Epoch 285/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0881 - categorical_accuracy: 0.3937
# Epoch 286/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0926 - categorical_accuracy: 0.3841
# Epoch 287/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0953 - categorical_accuracy: 0.3285
# Epoch 288/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0958 - categorical_accuracy: 0.3527
# Epoch 289/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0941 - categorical_accuracy: 0.3527
# Epoch 290/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0987 - categorical_accuracy: 0.3599
# Epoch 291/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0918 - categorical_accuracy: 0.3502
# Epoch 292/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.1020 - categorical_accuracy: 0.3696
# Epoch 293/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0991 - categorical_accuracy: 0.3502
# Epoch 294/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0910 - categorical_accuracy: 0.3502
# Epoch 295/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0951 - categorical_accuracy: 0.3841
# Epoch 296/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0952 - categorical_accuracy: 0.3454
# Epoch 297/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0976 - categorical_accuracy: 0.3478
# Epoch 298/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0912 - categorical_accuracy: 0.3382
# Epoch 299/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.1025 - categorical_accuracy: 0.3527
# Epoch 300/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0935 - categorical_accuracy: 0.3575
# Epoch 301/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0931 - categorical_accuracy: 0.3502
# Epoch 302/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0918 - categorical_accuracy: 0.3816
# Epoch 303/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0984 - categorical_accuracy: 0.3502
# Epoch 304/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0965 - categorical_accuracy: 0.3647
# Epoch 305/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0963 - categorical_accuracy: 0.3599
# Epoch 306/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0919 - categorical_accuracy: 0.3768
# Epoch 307/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0932 - categorical_accuracy: 0.3478
# Epoch 308/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.1005 - categorical_accuracy: 0.3841
# Epoch 309/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0988 - categorical_accuracy: 0.3333
# Epoch 310/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0987 - categorical_accuracy: 0.3430
# Epoch 311/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0860 - categorical_accuracy: 0.4010
# Epoch 312/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0895 - categorical_accuracy: 0.3720
# Epoch 313/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0887 - categorical_accuracy: 0.3986
# Epoch 314/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0969 - categorical_accuracy: 0.3478
# Epoch 315/1000
# 104/104 [==============================] - 102s 983ms/step - loss: 1.0954 - categorical_accuracy: 0.3430
# Epoch 316/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0951 - categorical_accuracy: 0.3454
# Epoch 317/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0916 - categorical_accuracy: 0.3720
# Epoch 318/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0934 - categorical_accuracy: 0.3696
# Epoch 319/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0966 - categorical_accuracy: 0.3261
# Epoch 320/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.1000 - categorical_accuracy: 0.3502
# Epoch 321/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0970 - categorical_accuracy: 0.3478
# Epoch 322/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0953 - categorical_accuracy: 0.3720
# Epoch 323/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0983 - categorical_accuracy: 0.3261
# Epoch 324/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0953 - categorical_accuracy: 0.3285
# Epoch 325/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0993 - categorical_accuracy: 0.3357
# Epoch 326/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0974 - categorical_accuracy: 0.3140
# Epoch 327/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0921 - categorical_accuracy: 0.3309
# Epoch 328/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0941 - categorical_accuracy: 0.3551
# Epoch 329/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0950 - categorical_accuracy: 0.3575
# Epoch 330/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0966 - categorical_accuracy: 0.3333
# Epoch 331/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0947 - categorical_accuracy: 0.3478
# Epoch 332/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0936 - categorical_accuracy: 0.3623
# Epoch 333/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0943 - categorical_accuracy: 0.3720
# Epoch 334/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0990 - categorical_accuracy: 0.3744
# Epoch 335/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0925 - categorical_accuracy: 0.3527
# Epoch 336/1000
# 104/104 [==============================] - 102s 983ms/step - loss: 1.0990 - categorical_accuracy: 0.2947
# Epoch 337/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0965 - categorical_accuracy: 0.3309
# Epoch 338/1000
# 104/104 [==============================] - 102s 983ms/step - loss: 1.0908 - categorical_accuracy: 0.3261
# Epoch 339/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0977 - categorical_accuracy: 0.3309
# Epoch 340/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0977 - categorical_accuracy: 0.3406
# Epoch 341/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0975 - categorical_accuracy: 0.3116
# Epoch 342/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0939 - categorical_accuracy: 0.3527
# Epoch 343/1000
# 104/104 [==============================] - 102s 983ms/step - loss: 1.0929 - categorical_accuracy: 0.3865
# Epoch 344/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0976 - categorical_accuracy: 0.3696
# Epoch 345/1000
# 104/104 [==============================] - 101s 972ms/step - loss: 1.0935 - categorical_accuracy: 0.3333
# Epoch 346/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0962 - categorical_accuracy: 0.3720
# Epoch 347/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0986 - categorical_accuracy: 0.3333
# Epoch 348/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0919 - categorical_accuracy: 0.3478
# Epoch 349/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0987 - categorical_accuracy: 0.3357
# Epoch 350/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0969 - categorical_accuracy: 0.3599
# Epoch 351/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0927 - categorical_accuracy: 0.3454
# Epoch 352/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0930 - categorical_accuracy: 0.3406
# Epoch 353/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0974 - categorical_accuracy: 0.3213
# Epoch 354/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0947 - categorical_accuracy: 0.3937
# Epoch 355/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0923 - categorical_accuracy: 0.3478
# Epoch 356/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0967 - categorical_accuracy: 0.3406
# Epoch 357/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0962 - categorical_accuracy: 0.3720
# Epoch 358/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.1004 - categorical_accuracy: 0.3237
# Epoch 359/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0987 - categorical_accuracy: 0.3261
# Epoch 360/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0962 - categorical_accuracy: 0.3575
# Epoch 361/1000
# 104/104 [==============================] - 101s 973ms/step - loss: 1.1012 - categorical_accuracy: 0.3188
# Epoch 362/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0976 - categorical_accuracy: 0.3430
# Epoch 363/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0846 - categorical_accuracy: 0.3744
# Epoch 364/1000
# 104/104 [==============================] - 101s 972ms/step - loss: 1.0923 - categorical_accuracy: 0.3599
# Epoch 365/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0977 - categorical_accuracy: 0.3454
# Epoch 366/1000
# 104/104 [==============================] - 101s 971ms/step - loss: 1.0933 - categorical_accuracy: 0.3720
# Epoch 367/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0954 - categorical_accuracy: 0.3478
# Epoch 368/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.1000 - categorical_accuracy: 0.3454
# Epoch 369/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0951 - categorical_accuracy: 0.3575
# Epoch 370/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0944 - categorical_accuracy: 0.3527
# Epoch 371/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.1000 - categorical_accuracy: 0.3333
# Epoch 372/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0982 - categorical_accuracy: 0.3527
# Epoch 373/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.1040 - categorical_accuracy: 0.3188
# Epoch 374/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0943 - categorical_accuracy: 0.3599
# Epoch 375/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0903 - categorical_accuracy: 0.3889
# Epoch 376/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0972 - categorical_accuracy: 0.3068
# Epoch 377/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0984 - categorical_accuracy: 0.3382
# Epoch 378/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0889 - categorical_accuracy: 0.3502
# Epoch 379/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0951 - categorical_accuracy: 0.3285
# Epoch 380/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0995 - categorical_accuracy: 0.3430
# Epoch 381/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0927 - categorical_accuracy: 0.3816
# Epoch 382/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0932 - categorical_accuracy: 0.3623
# Epoch 383/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0960 - categorical_accuracy: 0.3865
# Epoch 384/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0963 - categorical_accuracy: 0.3406
# Epoch 385/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.1012 - categorical_accuracy: 0.3164
# Epoch 386/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0928 - categorical_accuracy: 0.3527
# Epoch 387/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0970 - categorical_accuracy: 0.3816
# Epoch 388/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0914 - categorical_accuracy: 0.3454
# Epoch 389/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0930 - categorical_accuracy: 0.3720
# Epoch 390/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0986 - categorical_accuracy: 0.2874
# Epoch 391/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0958 - categorical_accuracy: 0.3068
# Epoch 392/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0969 - categorical_accuracy: 0.3164
# Epoch 393/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0995 - categorical_accuracy: 0.3478
# Epoch 394/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0967 - categorical_accuracy: 0.3237
# Epoch 395/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0994 - categorical_accuracy: 0.3406
# Epoch 396/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0914 - categorical_accuracy: 0.3647
# Epoch 397/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0935 - categorical_accuracy: 0.3671
# Epoch 398/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0892 - categorical_accuracy: 0.3816
# Epoch 399/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0871 - categorical_accuracy: 0.3357
# Epoch 400/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0898 - categorical_accuracy: 0.3792
# Epoch 401/1000
# ...
# Epoch 718/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0976 - categorical_accuracy: 0.3454
# Epoch 719/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0953 - categorical_accuracy: 0.3816
# Epoch 720/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0907 - categorical_accuracy: 0.3913
# Epoch 721/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0919 - categorical_accuracy: 0.3502
# Epoch 722/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0918 - categorical_accuracy: 0.3696
# Epoch 723/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0931 - categorical_accuracy: 0.3671
# Epoch 724/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0936 - categorical_accuracy: 0.4034
# Epoch 725/1000
# 104/104 [==============================] - 102s 983ms/step - loss: 1.0956 - categorical_accuracy: 0.3406
# Epoch 726/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0959 - categorical_accuracy: 0.3043
# Epoch 727/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0914 - categorical_accuracy: 0.3744
# Epoch 728/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0884 - categorical_accuracy: 0.4034
# Epoch 729/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0974 - categorical_accuracy: 0.3502
# Epoch 730/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0937 - categorical_accuracy: 0.3744
# Epoch 731/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0973 - categorical_accuracy: 0.3406
# Epoch 732/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0985 - categorical_accuracy: 0.3671
# Epoch 733/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0955 - categorical_accuracy: 0.3285
# Epoch 734/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0950 - categorical_accuracy: 0.3430
# Epoch 735/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0953 - categorical_accuracy: 0.3527
# Epoch 736/1000
# 104/104 [==============================] - 103s 986ms/step - loss: 1.0933 - categorical_accuracy: 0.3430
# Epoch 737/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0974 - categorical_accuracy: 0.3261
# Epoch 738/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0925 - categorical_accuracy: 0.3454
# Epoch 739/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0997 - categorical_accuracy: 0.3333
# Epoch 740/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0959 - categorical_accuracy: 0.4082
# Epoch 741/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0947 - categorical_accuracy: 0.3285
# Epoch 742/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0962 - categorical_accuracy: 0.3599
# Epoch 743/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0901 - categorical_accuracy: 0.4203
# Epoch 744/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0947 - categorical_accuracy: 0.3816
# Epoch 745/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0968 - categorical_accuracy: 0.3213
# Epoch 746/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0973 - categorical_accuracy: 0.3237
# Epoch 747/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0961 - categorical_accuracy: 0.3478
# Epoch 748/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0916 - categorical_accuracy: 0.3164
# Epoch 749/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.1002 - categorical_accuracy: 0.3454
# Epoch 750/1000
# 104/104 [==============================] - 101s 973ms/step - loss: 1.1014 - categorical_accuracy: 0.3333
# Epoch 751/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0943 - categorical_accuracy: 0.3986
# Epoch 752/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0958 - categorical_accuracy: 0.3768
# Epoch 753/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0934 - categorical_accuracy: 0.3333
# Epoch 754/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0964 - categorical_accuracy: 0.3744
# Epoch 755/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0943 - categorical_accuracy: 0.3502
# Epoch 756/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0940 - categorical_accuracy: 0.3382
# Epoch 757/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0902 - categorical_accuracy: 0.3551
# Epoch 758/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0947 - categorical_accuracy: 0.3285
# Epoch 759/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0956 - categorical_accuracy: 0.3406
# Epoch 760/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0943 - categorical_accuracy: 0.3382
# Epoch 761/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0981 - categorical_accuracy: 0.2947
# Epoch 762/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0962 - categorical_accuracy: 0.3792
# Epoch 763/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0917 - categorical_accuracy: 0.3671
# Epoch 764/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0961 - categorical_accuracy: 0.3841
# Epoch 765/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0974 - categorical_accuracy: 0.3575
# Epoch 766/1000
# 104/104 [==============================] - 101s 976ms/step - loss: 1.0963 - categorical_accuracy: 0.3430
# Epoch 767/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.1002 - categorical_accuracy: 0.2874
# Epoch 768/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.0973 - categorical_accuracy: 0.3261
# Epoch 769/1000
# 104/104 [==============================] - 101s 973ms/step - loss: 1.0968 - categorical_accuracy: 0.3527
# Epoch 770/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0969 - categorical_accuracy: 0.3333
# Epoch 771/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.1033 - categorical_accuracy: 0.3551
# Epoch 772/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0923 - categorical_accuracy: 0.3527
# Epoch 773/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0959 - categorical_accuracy: 0.3478
# Epoch 774/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0946 - categorical_accuracy: 0.3551
# Epoch 775/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0938 - categorical_accuracy: 0.3333
# Epoch 776/1000
# 104/104 [==============================] - 101s 974ms/step - loss: 1.1040 - categorical_accuracy: 0.3188
# Epoch 777/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0965 - categorical_accuracy: 0.3237
# Epoch 778/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0915 - categorical_accuracy: 0.3792
# Epoch 779/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0971 - categorical_accuracy: 0.3478
# Epoch 780/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0968 - categorical_accuracy: 0.3599
# Epoch 781/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.1015 - categorical_accuracy: 0.3382
# Epoch 782/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0967 - categorical_accuracy: 0.3575
# Epoch 783/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0990 - categorical_accuracy: 0.3502
# Epoch 784/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0915 - categorical_accuracy: 0.3696
# Epoch 785/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0888 - categorical_accuracy: 0.3575
# Epoch 786/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0963 - categorical_accuracy: 0.3406
# Epoch 787/1000
# 104/104 [==============================] - 102s 985ms/step - loss: 1.0991 - categorical_accuracy: 0.3406
# Epoch 788/1000
# 104/104 [==============================] - 102s 984ms/step - loss: 1.0973 - categorical_accuracy: 0.3478
# Epoch 789/1000
# 104/104 [==============================] - 101s 975ms/step - loss: 1.0934 - categorical_accuracy: 0.3671
# Epoch 790/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0985 - categorical_accuracy: 0.3551
# Epoch 791/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0905 - categorical_accuracy: 0.3261
# Epoch 792/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0952 - categorical_accuracy: 0.3478
# Epoch 793/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0941 - categorical_accuracy: 0.3527
# Epoch 794/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0906 - categorical_accuracy: 0.3889
# Epoch 795/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0936 - categorical_accuracy: 0.3623
# Epoch 796/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0949 - categorical_accuracy: 0.3551
# Epoch 797/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0947 - categorical_accuracy: 0.3841
# Epoch 798/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0990 - categorical_accuracy: 0.3333
# Epoch 799/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0909 - categorical_accuracy: 0.3647
# Epoch 800/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0882 - categorical_accuracy: 0.3841
# Epoch 801/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0957 - categorical_accuracy: 0.3406
# Epoch 802/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0963 - categorical_accuracy: 0.3333
# Epoch 803/1000
# 104/104 [==============================] - 102s 982ms/step - loss: 1.0952 - categorical_accuracy: 0.3816
# Epoch 804/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0959 - categorical_accuracy: 0.3357
# Epoch 805/1000
# 104/104 [==============================] - 102s 977ms/step - loss: 1.0943 - categorical_accuracy: 0.3575
# Epoch 806/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0946 - categorical_accuracy: 0.3406
# Epoch 807/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0911 - categorical_accuracy: 0.3599
# Epoch 808/1000
# 104/104 [==============================] - 102s 981ms/step - loss: 1.0964 - categorical_accuracy: 0.3357
# Epoch 809/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0923 - categorical_accuracy: 0.3478
# Epoch 810/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0986 - categorical_accuracy: 0.3599
# Epoch 811/1000
# 104/104 [==============================] - 102s 980ms/step - loss: 1.0954 - categorical_accuracy: 0.3237
# Epoch 812/1000
# 104/104 [==============================] - 102s 978ms/step - loss: 1.0968 - categorical_accuracy: 0.3285
# Epoch 813/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0924 - categorical_accuracy: 0.3599
# Epoch 814/1000
# 104/104 [==============================] - 102s 979ms/step - loss: 1.0962 - categorical_accuracy: 0.3406
# Epoch 815/1000
# 104/104 [==============================] - 102s 976ms/step - loss: 1.0906 - categorical_accuracy: 0.4082
# Epoch 816/1000
#  42/104 [===========>..................] - ETA: 59s - loss: 1.0814 - categorical_accuracy: 0.4405
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-5d08b223ae34> in <module>
#       1 # %%time
# ----> 2 model.fit(dd, epochs=1000, verbose=1,workers=4, callbacks=[reduce_lr,lr_sched, tensorboard])
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
