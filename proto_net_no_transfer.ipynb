# %%
import os
import cv2
import numpy as np
from glob import glob
from tqdm import tqdm
import matplotlib.pyplot as plt
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Lambda, Dense, Dropout, Conv2D, MaxPooling2D, Flatten,Activation,BatchNormalization
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.losses import CategoricalCrossentropy

from tensorflow.keras.applications.efficientnet import preprocess_input,EfficientNetB0

from tensorflow.keras import callbacks as cb
from tensorflow.keras import backend as K
from tensorflow.keras import utils
from sklearn.model_selection import train_test_split

gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth( device=gpu, enable=True)

# %%
all_classes = glob('/home/jovyan/data/fungi/images/*')
source_classes,target_classes=train_test_split(all_classes,test_size=0.1)
sorce_len=len(source_classes)
target_len=len(target_classes)
print(f"total {len(all_classes)} classes=source {sorce_len} + target {target_len} classes")
# Out:
# total 1394 classes=source 1254 + target 140 classes

# %%
W,H,CH = 224,224,3
# W,H,CH = 64,64,3
def load_img(path, width = W):
#     img = cv2.cvtColor(cv2.imread(path), cv2.COLOR_BGR2RGB).astype(np.float32)/255.0
    img = tf.io.read_file(path)
#     img = tf.image.decode_jpeg(img, channels=CH)
    img = tf.image.decode_jpeg(img, channels=CH)/255
    img = img.numpy()
    
    shape_dst = np.min(img.shape[:2])
    oh = (img.shape[0] - shape_dst) // 2
    ow = (img.shape[1] - shape_dst) // 2
    center_square = np.array([width,width])// 2
    new_size=(width,width)
    
    # cropping + resize
    img = img[oh:oh + shape_dst, ow:ow + shape_dst]
    img=cv2.resize(img, new_size)
    
    # Random affine+rotation
#     random_state = np.random.RandomState(seed=None)
#     alpha_affine=img.shape[0] * 0.1
#     pts1 = np.float32([center_square + width, 
#                        [center_square[0]+width, center_square[1]-width],
#                        center_square - width])
#     pts2 = pts1 + random_state.uniform(-alpha_affine, alpha_affine, size=pts1.shape).astype(np.float32)
#     M = cv2.getAffineTransform(pts1, pts2)
#     rot_mat = cv2.getRotationMatrix2D(tuple(center_square),random_state.rand()*360., 1.0)
#     img = cv2.warpAffine(img, M, new_size, borderMode=cv2.BORDER_REPLICATE)
#     img = cv2.warpAffine(img, rot_mat, new_size, borderMode=cv2.BORDER_REPLICATE)
    return tf.constant(img)

# %%
WAYS = 3
SHOTS=5
QUERIES=1
BATCH_SIZE=4

# %%
min([len(glob(sdir+'/*.JPG')) for sdir in source_classes])
# Out:
# 6

# %%
## exclude classes with too few examples
source_classes=[sdir for sdir in source_classes if len(glob(sdir+'/*.JPG'))>SHOTS+QUERIES]

sorce_len=len(source_classes)
print(f"source {sorce_len} + target {target_len} classes")
# Out:
# source 1242 + target 140 classes

# %%
min([len(glob(sdir+'/*.JPG')) for sdir in source_classes])
# Out:
# 7

# %%
map_fun=lambda string: tf.py_function(func=load_img,inp=[string], Tout=tf.float32)
all_sub = [
    tf.data.Dataset.list_files(sc+'/*.JPG', shuffle=True)
    .map(map_fun)
    for sc in source_classes
]

def gen():
    supports = []
    querys = []
    order=np.random.permutation(len(all_sub))
    for tasks in range(len(all_sub)//WAYS):
        picked=[all_sub[tt] for tt in order[WAYS*tasks:WAYS*(tasks+1)]]
        support = tf.concat(
            [
                next(
                    iter(
                        sub.batch(SHOTS).prefetch(SHOTS)
                    )
                    ) for sub in picked
            ]
            , axis=0)
        idxs=np.random.choice(range(WAYS), size=QUERIES, replace=False)
        query = tf.concat(
            [
                next(
                    iter(
                        picked[idx].batch(1).prefetch(1)
                    )
                    ) for idx in idxs
            ]
            , axis=0)
        yield tf.concat([support, query], axis=0), tuple([keras.utils.to_categorical(idx,num_classes=WAYS) for idx in idxs])
dd = tf.data.Dataset.from_generator(gen,
                                    output_types=(tf.float32,tuple([tf.float32]*QUERIES)),
                                    output_shapes=((WAYS*SHOTS+QUERIES,W,H,CH),tuple([WAYS]*QUERIES))
                                   ).batch(BATCH_SIZE)

# %%
def conv_net(input_shape):
    convnet = Sequential()
    for i in range(4):
        convnet.add(Conv2D(64,(3,3),padding='valid',input_shape=input_shape))
        convnet.add(BatchNormalization())
        convnet.add(Activation('relu'))
        convnet.add(MaxPooling2D())
    convnet.add(Flatten())
    return convnet
def pretrain_net(input_shape):
    base_model = EfficientNetB0(weights=None, include_top=False)
    x_in=Input(shape=(W,H,CH))
    x=preprocess_input(x_in)
    out=Flatten()(base_model(x))
    model = Model(inputs=x_in, outputs=out)
    return model
def euclidean_distance(f_1,f_2):
    """
    Euclidean distance loss
    https://en.wikipedia.org/wiki/Euclidean_distance
    :param y_true: TensorFlow/Theano tensor
    :param y_pred: TensorFlow/Theano tensor of the same shape as y_true
    :return: float
    """
    return K.sqrt(K.sum(K.square(f_1 - f_2), axis=-1))

# %%
base_dim = (W,H,CH)
base_network = pretrain_net(base_dim)
# Query feature
x_in=Input(shape=(WAYS*SHOTS+QUERIES,W,H,CH))
latent_s=[base_network(x_in[:,ii]) for ii in range(WAYS*SHOTS)]
latent_q=[base_network(x_in[:,WAYS*SHOTS+ii]) for ii in range(QUERIES)]

y=list()
for qq in range(QUERIES):
    dist_scores=list()
    for ww in range(WAYS):
        latent_proto=tf.reduce_mean(tf.stack(latent_s[ww*SHOTS:(ww+1)*SHOTS],axis=-1),axis=-1)
        dist_avg=euclidean_distance(latent_q[qq],latent_proto)
        dist_scores.append(dist_avg)
    y.append(tf.nn.softmax(-tf.stack(dist_scores,axis=-1),axis=-1))

model = Model(inputs=x_in, outputs=tuple(y))

# %%
lr=0.001
def scheduler(epoch):
    global lr
    if epoch % 3 == 0:
        lr /= 2
    return lr
reduce_lr = cb.ReduceLROnPlateau(monitor='loss', factor=0.4,patience=2, min_lr=1e-8)
lr_sched = cb.LearningRateScheduler(scheduler)
tensorboard = cb.TensorBoard()
opt = tf.keras.optimizers.Adam(lr=0.002)
model.compile(loss=CategoricalCrossentropy(), optimizer=opt, metrics=['categorical_accuracy'])

# %%
# %%time
model.fit(dd, epochs=1000, verbose=1,workers=4, callbacks=[reduce_lr,lr_sched, tensorboard])
# Out:
# Epoch 1/1000
#       2/Unknown - 9s 5s/step - loss: 1.0872 - categorical_accuracy: 0.6250  WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 1.5016s vs `on_train_batch_end` time: 7.9563s). Check your callbacks.
# 104/104 [==============================] - 156s 2s/step - loss: 1.1693 - categorical_accuracy: 0.5024
# Epoch 2/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.2382 - categorical_accuracy: 0.4662
# Epoch 3/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.2865 - categorical_accuracy: 0.4372
# Epoch 4/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.2059 - categorical_accuracy: 0.4541
# Epoch 5/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1517 - categorical_accuracy: 0.4638
# Epoch 6/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1122 - categorical_accuracy: 0.5242
# Epoch 7/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1341 - categorical_accuracy: 0.4541
# Epoch 8/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0348 - categorical_accuracy: 0.4976
# Epoch 9/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1125 - categorical_accuracy: 0.4662
# Epoch 10/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0547 - categorical_accuracy: 0.5000
# Epoch 11/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1282 - categorical_accuracy: 0.4589
# Epoch 12/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0759 - categorical_accuracy: 0.4879
# Epoch 13/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1357 - categorical_accuracy: 0.4614
# Epoch 14/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0644 - categorical_accuracy: 0.5121
# Epoch 15/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0740 - categorical_accuracy: 0.4903
# Epoch 16/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0680 - categorical_accuracy: 0.4758
# Epoch 17/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0574 - categorical_accuracy: 0.4638
# Epoch 18/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0567 - categorical_accuracy: 0.4976
# Epoch 19/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0189 - categorical_accuracy: 0.5072
# Epoch 20/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9891 - categorical_accuracy: 0.5242
# Epoch 21/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0882 - categorical_accuracy: 0.4928
# Epoch 22/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0573 - categorical_accuracy: 0.4614
# Epoch 23/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0771 - categorical_accuracy: 0.4662
# Epoch 24/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0545 - categorical_accuracy: 0.4831
# Epoch 25/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1290 - categorical_accuracy: 0.4444
# Epoch 26/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9811 - categorical_accuracy: 0.5314
# Epoch 27/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0001 - categorical_accuracy: 0.5242
# Epoch 28/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0008 - categorical_accuracy: 0.5266
# Epoch 29/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0677 - categorical_accuracy: 0.4976
# Epoch 30/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0732 - categorical_accuracy: 0.4783
# Epoch 31/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0396 - categorical_accuracy: 0.4952
# Epoch 32/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9899 - categorical_accuracy: 0.5411
# Epoch 33/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0048 - categorical_accuracy: 0.5362
# Epoch 34/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0064 - categorical_accuracy: 0.5193
# Epoch 35/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0035 - categorical_accuracy: 0.5338
# Epoch 36/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0676 - categorical_accuracy: 0.4783
# Epoch 37/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0668 - categorical_accuracy: 0.4783
# Epoch 38/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0324 - categorical_accuracy: 0.4952
# Epoch 39/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0946 - categorical_accuracy: 0.4855
# Epoch 40/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0380 - categorical_accuracy: 0.5217
# Epoch 41/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0135 - categorical_accuracy: 0.5169
# Epoch 42/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0452 - categorical_accuracy: 0.4879
# Epoch 43/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1095 - categorical_accuracy: 0.4517
# Epoch 44/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0945 - categorical_accuracy: 0.4710
# Epoch 45/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1068 - categorical_accuracy: 0.4614
# Epoch 46/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0384 - categorical_accuracy: 0.5121
# Epoch 47/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0222 - categorical_accuracy: 0.5169
# Epoch 48/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1110 - categorical_accuracy: 0.4420
# Epoch 49/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0581 - categorical_accuracy: 0.4710
# Epoch 50/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0453 - categorical_accuracy: 0.4686
# Epoch 51/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9517 - categorical_accuracy: 0.5169
# Epoch 52/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0188 - categorical_accuracy: 0.5097
# Epoch 53/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0843 - categorical_accuracy: 0.4758
# Epoch 54/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0388 - categorical_accuracy: 0.5000
# Epoch 55/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1253 - categorical_accuracy: 0.4565
# Epoch 56/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9696 - categorical_accuracy: 0.5290
# Epoch 57/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0350 - categorical_accuracy: 0.4831
# Epoch 58/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1295 - categorical_accuracy: 0.4614
# Epoch 59/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0807 - categorical_accuracy: 0.4879
# Epoch 60/1000
# 104/104 [==============================] - 147s 1s/step - loss: 1.0407 - categorical_accuracy: 0.4879
# Epoch 61/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0223 - categorical_accuracy: 0.5217
# Epoch 62/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0210 - categorical_accuracy: 0.4758
# Epoch 63/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0599 - categorical_accuracy: 0.4952
# Epoch 64/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0709 - categorical_accuracy: 0.4903
# Epoch 65/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0326 - categorical_accuracy: 0.5193
# Epoch 66/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0229 - categorical_accuracy: 0.5459
# Epoch 67/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0096 - categorical_accuracy: 0.5121
# Epoch 68/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0834 - categorical_accuracy: 0.4903
# Epoch 69/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0878 - categorical_accuracy: 0.4493
# Epoch 70/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1050 - categorical_accuracy: 0.4396
# Epoch 71/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0857 - categorical_accuracy: 0.4879
# Epoch 72/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0729 - categorical_accuracy: 0.5097
# Epoch 73/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1136 - categorical_accuracy: 0.4638
# Epoch 74/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1241 - categorical_accuracy: 0.4348
# Epoch 75/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0495 - categorical_accuracy: 0.5097
# Epoch 76/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1261 - categorical_accuracy: 0.4734
# Epoch 77/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0655 - categorical_accuracy: 0.4903
# Epoch 78/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9835 - categorical_accuracy: 0.5193
# Epoch 79/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0518 - categorical_accuracy: 0.4807
# Epoch 80/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0233 - categorical_accuracy: 0.5145
# Epoch 81/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0593 - categorical_accuracy: 0.4855
# Epoch 82/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0615 - categorical_accuracy: 0.5000
# Epoch 83/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0697 - categorical_accuracy: 0.5048
# Epoch 84/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0225 - categorical_accuracy: 0.5097
# Epoch 85/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1151 - categorical_accuracy: 0.4541
# Epoch 86/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0537 - categorical_accuracy: 0.4903
# Epoch 87/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0877 - categorical_accuracy: 0.5000
# Epoch 88/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0775 - categorical_accuracy: 0.4879
# Epoch 89/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0653 - categorical_accuracy: 0.4758
# Epoch 90/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0969 - categorical_accuracy: 0.4517
# Epoch 91/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9509 - categorical_accuracy: 0.5725
# Epoch 92/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1332 - categorical_accuracy: 0.4469
# Epoch 93/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0495 - categorical_accuracy: 0.5024
# Epoch 94/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0294 - categorical_accuracy: 0.4903
# Epoch 95/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0926 - categorical_accuracy: 0.4758
# Epoch 96/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0450 - categorical_accuracy: 0.4444
# Epoch 97/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0917 - categorical_accuracy: 0.4928
# Epoch 98/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0491 - categorical_accuracy: 0.4855
# Epoch 99/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0514 - categorical_accuracy: 0.4807
# Epoch 100/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0417 - categorical_accuracy: 0.5266
# Epoch 101/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1154 - categorical_accuracy: 0.4517
# Epoch 102/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0142 - categorical_accuracy: 0.5024
# Epoch 103/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0072 - categorical_accuracy: 0.5024
# Epoch 104/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0811 - categorical_accuracy: 0.4807
# Epoch 105/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0844 - categorical_accuracy: 0.5024
# Epoch 106/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9856 - categorical_accuracy: 0.5242
# Epoch 107/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0104 - categorical_accuracy: 0.4855
# Epoch 108/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0207 - categorical_accuracy: 0.5169
# Epoch 109/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0248 - categorical_accuracy: 0.4879
# Epoch 110/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0900 - categorical_accuracy: 0.4903
# Epoch 111/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0095 - categorical_accuracy: 0.5290
# Epoch 112/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0117 - categorical_accuracy: 0.5024
# Epoch 113/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0287 - categorical_accuracy: 0.5386
# Epoch 114/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0559 - categorical_accuracy: 0.5145
# Epoch 115/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0218 - categorical_accuracy: 0.4783
# Epoch 116/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0829 - categorical_accuracy: 0.4493
# Epoch 117/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9732 - categorical_accuracy: 0.5242
# Epoch 118/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0875 - categorical_accuracy: 0.4855
# Epoch 119/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0508 - categorical_accuracy: 0.5024
# Epoch 120/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0207 - categorical_accuracy: 0.4976
# Epoch 121/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1433 - categorical_accuracy: 0.4324
# Epoch 122/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0576 - categorical_accuracy: 0.4855
# Epoch 123/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0496 - categorical_accuracy: 0.4879
# Epoch 124/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0978 - categorical_accuracy: 0.4976
# Epoch 125/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0505 - categorical_accuracy: 0.4710
# Epoch 126/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0761 - categorical_accuracy: 0.4420
# Epoch 127/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0250 - categorical_accuracy: 0.5169
# Epoch 128/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1175 - categorical_accuracy: 0.4179
# Epoch 129/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0586 - categorical_accuracy: 0.4976
# Epoch 130/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9767 - categorical_accuracy: 0.5362
# Epoch 131/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0038 - categorical_accuracy: 0.5386
# Epoch 132/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0618 - categorical_accuracy: 0.4952
# Epoch 133/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0465 - categorical_accuracy: 0.4928
# Epoch 134/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0697 - categorical_accuracy: 0.4879
# Epoch 135/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0461 - categorical_accuracy: 0.5072
# Epoch 136/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0763 - categorical_accuracy: 0.5193
# Epoch 137/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0465 - categorical_accuracy: 0.4855
# Epoch 138/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0671 - categorical_accuracy: 0.4903
# Epoch 139/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0965 - categorical_accuracy: 0.4758
# Epoch 140/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9839 - categorical_accuracy: 0.5362
# Epoch 141/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1357 - categorical_accuracy: 0.4493
# Epoch 142/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0380 - categorical_accuracy: 0.4976
# Epoch 143/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9975 - categorical_accuracy: 0.5072
# Epoch 144/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0215 - categorical_accuracy: 0.5290
# Epoch 145/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0475 - categorical_accuracy: 0.5072
# Epoch 146/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0865 - categorical_accuracy: 0.4758
# Epoch 147/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0195 - categorical_accuracy: 0.4952
# Epoch 148/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9639 - categorical_accuracy: 0.5266
# Epoch 149/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0698 - categorical_accuracy: 0.4855
# Epoch 150/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1009 - categorical_accuracy: 0.4614
# Epoch 151/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0226 - categorical_accuracy: 0.4783
# Epoch 152/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1154 - categorical_accuracy: 0.4710
# Epoch 153/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0356 - categorical_accuracy: 0.4783
# Epoch 154/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1077 - categorical_accuracy: 0.4783
# Epoch 155/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0524 - categorical_accuracy: 0.4686
# Epoch 156/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0609 - categorical_accuracy: 0.5048
# Epoch 157/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0104 - categorical_accuracy: 0.5266
# Epoch 158/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0383 - categorical_accuracy: 0.4976
# Epoch 159/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0942 - categorical_accuracy: 0.4517
# Epoch 160/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0674 - categorical_accuracy: 0.4879
# Epoch 161/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1004 - categorical_accuracy: 0.4444
# Epoch 162/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0219 - categorical_accuracy: 0.5024
# Epoch 163/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0020 - categorical_accuracy: 0.5097
# Epoch 164/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0671 - categorical_accuracy: 0.5024
# Epoch 165/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0377 - categorical_accuracy: 0.4928
# Epoch 166/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9505 - categorical_accuracy: 0.5362
# Epoch 167/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0149 - categorical_accuracy: 0.5000
# Epoch 168/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9883 - categorical_accuracy: 0.5266
# Epoch 169/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0840 - categorical_accuracy: 0.4758
# Epoch 170/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0861 - categorical_accuracy: 0.4758
# Epoch 171/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1224 - categorical_accuracy: 0.4734
# Epoch 172/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1293 - categorical_accuracy: 0.4517
# Epoch 173/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0380 - categorical_accuracy: 0.4783
# Epoch 174/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0117 - categorical_accuracy: 0.4855
# Epoch 175/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9917 - categorical_accuracy: 0.5193
# Epoch 176/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0630 - categorical_accuracy: 0.5217
# Epoch 177/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0704 - categorical_accuracy: 0.4686
# Epoch 178/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0522 - categorical_accuracy: 0.5169
# Epoch 179/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0517 - categorical_accuracy: 0.5024
# Epoch 180/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0180 - categorical_accuracy: 0.4928
# Epoch 181/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0448 - categorical_accuracy: 0.4662
# Epoch 182/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0189 - categorical_accuracy: 0.4831
# Epoch 183/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1137 - categorical_accuracy: 0.4734
# Epoch 184/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0524 - categorical_accuracy: 0.5072
# Epoch 185/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0238 - categorical_accuracy: 0.4879
# Epoch 186/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0711 - categorical_accuracy: 0.4952
# Epoch 187/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9549 - categorical_accuracy: 0.5459
# Epoch 188/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0097 - categorical_accuracy: 0.5338
# Epoch 189/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0681 - categorical_accuracy: 0.4807
# Epoch 190/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0981 - categorical_accuracy: 0.4783
# Epoch 191/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0877 - categorical_accuracy: 0.4614
# Epoch 192/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0390 - categorical_accuracy: 0.5024
# Epoch 193/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0056 - categorical_accuracy: 0.5242
# Epoch 194/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0525 - categorical_accuracy: 0.5024
# Epoch 195/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9932 - categorical_accuracy: 0.4976
# Epoch 196/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0764 - categorical_accuracy: 0.4614
# Epoch 197/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0307 - categorical_accuracy: 0.5145
# Epoch 198/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0789 - categorical_accuracy: 0.4976
# Epoch 199/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0996 - categorical_accuracy: 0.4734
# Epoch 200/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0565 - categorical_accuracy: 0.4734
# Epoch 201/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9926 - categorical_accuracy: 0.5266
# Epoch 202/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0699 - categorical_accuracy: 0.4928
# Epoch 203/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9735 - categorical_accuracy: 0.5217
# Epoch 204/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0397 - categorical_accuracy: 0.5145
# Epoch 205/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0622 - categorical_accuracy: 0.4855
# Epoch 206/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0131 - categorical_accuracy: 0.4734
# Epoch 207/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0748 - categorical_accuracy: 0.4952
# Epoch 208/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0291 - categorical_accuracy: 0.4734
# Epoch 209/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0010 - categorical_accuracy: 0.4952
# Epoch 210/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1109 - categorical_accuracy: 0.4638
# Epoch 211/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9824 - categorical_accuracy: 0.5145
# Epoch 212/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0713 - categorical_accuracy: 0.4879
# Epoch 213/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0748 - categorical_accuracy: 0.4517
# Epoch 214/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0431 - categorical_accuracy: 0.4976
# Epoch 215/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0196 - categorical_accuracy: 0.5097
# Epoch 216/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0636 - categorical_accuracy: 0.4686
# Epoch 217/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0105 - categorical_accuracy: 0.5097
# Epoch 218/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0692 - categorical_accuracy: 0.4928
# Epoch 219/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0403 - categorical_accuracy: 0.4903
# Epoch 220/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0393 - categorical_accuracy: 0.5193
# Epoch 221/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0787 - categorical_accuracy: 0.4903
# Epoch 222/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0383 - categorical_accuracy: 0.5121
# Epoch 223/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1015 - categorical_accuracy: 0.4734
# Epoch 224/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1069 - categorical_accuracy: 0.4734
# Epoch 225/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0987 - categorical_accuracy: 0.5000
# Epoch 226/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9973 - categorical_accuracy: 0.5386
# Epoch 227/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0619 - categorical_accuracy: 0.4855
# Epoch 228/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1155 - categorical_accuracy: 0.4541
# Epoch 229/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0192 - categorical_accuracy: 0.5145
# Epoch 230/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0699 - categorical_accuracy: 0.4807
# Epoch 231/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0928 - categorical_accuracy: 0.4638
# Epoch 232/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1235 - categorical_accuracy: 0.4444
# Epoch 233/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0690 - categorical_accuracy: 0.5169
# Epoch 234/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0588 - categorical_accuracy: 0.4952
# Epoch 235/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0972 - categorical_accuracy: 0.4565
# Epoch 236/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0735 - categorical_accuracy: 0.4565
# Epoch 237/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9715 - categorical_accuracy: 0.5507
# Epoch 238/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0979 - categorical_accuracy: 0.4734
# Epoch 239/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0089 - categorical_accuracy: 0.5290
# Epoch 240/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0515 - categorical_accuracy: 0.4855
# Epoch 241/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0231 - categorical_accuracy: 0.5217
# Epoch 242/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0511 - categorical_accuracy: 0.4831
# Epoch 243/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0248 - categorical_accuracy: 0.4952
# Epoch 244/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0939 - categorical_accuracy: 0.4783
# Epoch 245/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0978 - categorical_accuracy: 0.4686
# Epoch 246/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0717 - categorical_accuracy: 0.4976
# Epoch 247/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0351 - categorical_accuracy: 0.4952
# Epoch 248/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0305 - categorical_accuracy: 0.4638
# Epoch 249/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0737 - categorical_accuracy: 0.4976
# Epoch 250/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0905 - categorical_accuracy: 0.4589
# Epoch 251/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9861 - categorical_accuracy: 0.5145
# Epoch 252/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0428 - categorical_accuracy: 0.5024
# Epoch 253/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0474 - categorical_accuracy: 0.4952
# Epoch 254/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0608 - categorical_accuracy: 0.4855
# Epoch 255/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9928 - categorical_accuracy: 0.5193
# Epoch 256/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0274 - categorical_accuracy: 0.4710
# Epoch 257/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1007 - categorical_accuracy: 0.4662
# Epoch 258/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0229 - categorical_accuracy: 0.5048
# Epoch 259/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0835 - categorical_accuracy: 0.4879
# Epoch 260/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9842 - categorical_accuracy: 0.5121
# Epoch 261/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0341 - categorical_accuracy: 0.5145
# Epoch 262/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0889 - categorical_accuracy: 0.5000
# Epoch 263/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0514 - categorical_accuracy: 0.5217
# Epoch 264/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1429 - categorical_accuracy: 0.4662
# Epoch 265/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0692 - categorical_accuracy: 0.4855
# Epoch 266/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0461 - categorical_accuracy: 0.5048
# Epoch 267/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1025 - categorical_accuracy: 0.4831
# Epoch 268/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0216 - categorical_accuracy: 0.5048
# Epoch 269/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9952 - categorical_accuracy: 0.5145
# Epoch 270/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0076 - categorical_accuracy: 0.4855
# Epoch 271/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0830 - categorical_accuracy: 0.5048
# Epoch 272/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0664 - categorical_accuracy: 0.4952
# Epoch 273/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9897 - categorical_accuracy: 0.5193
# Epoch 274/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0698 - categorical_accuracy: 0.4686
# Epoch 275/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9917 - categorical_accuracy: 0.5193
# Epoch 276/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0612 - categorical_accuracy: 0.4879
# Epoch 277/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0870 - categorical_accuracy: 0.4976
# Epoch 278/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0073 - categorical_accuracy: 0.5193
# Epoch 279/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0215 - categorical_accuracy: 0.4976
# Epoch 280/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0840 - categorical_accuracy: 0.5000
# Epoch 281/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0869 - categorical_accuracy: 0.4638
# Epoch 282/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0935 - categorical_accuracy: 0.4879
# Epoch 283/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0953 - categorical_accuracy: 0.4734
# Epoch 284/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0404 - categorical_accuracy: 0.4928
# Epoch 285/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0688 - categorical_accuracy: 0.4589
# Epoch 286/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1437 - categorical_accuracy: 0.4444
# Epoch 287/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0826 - categorical_accuracy: 0.4952
# Epoch 288/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1356 - categorical_accuracy: 0.4710
# Epoch 289/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0928 - categorical_accuracy: 0.4855
# Epoch 290/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0802 - categorical_accuracy: 0.4879
# Epoch 291/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0624 - categorical_accuracy: 0.4686
# Epoch 292/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0522 - categorical_accuracy: 0.5338
# Epoch 293/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0928 - categorical_accuracy: 0.4710
# Epoch 294/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0086 - categorical_accuracy: 0.5121
# Epoch 295/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0774 - categorical_accuracy: 0.4638
# Epoch 296/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0078 - categorical_accuracy: 0.5217
# Epoch 297/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0645 - categorical_accuracy: 0.5024
# Epoch 298/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0794 - categorical_accuracy: 0.4831
# Epoch 299/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0708 - categorical_accuracy: 0.4831
# Epoch 300/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9903 - categorical_accuracy: 0.5072
# Epoch 301/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0557 - categorical_accuracy: 0.4903
# Epoch 302/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0063 - categorical_accuracy: 0.5217
# Epoch 303/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0843 - categorical_accuracy: 0.4831
# Epoch 304/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0710 - categorical_accuracy: 0.5000
# Epoch 305/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0329 - categorical_accuracy: 0.5145
# Epoch 306/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9708 - categorical_accuracy: 0.4903
# Epoch 307/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0957 - categorical_accuracy: 0.4952
# Epoch 308/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0621 - categorical_accuracy: 0.4903
# Epoch 309/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0228 - categorical_accuracy: 0.4952
# Epoch 310/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0396 - categorical_accuracy: 0.4903
# Epoch 311/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0185 - categorical_accuracy: 0.5242
# Epoch 312/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0529 - categorical_accuracy: 0.4879
# Epoch 313/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0433 - categorical_accuracy: 0.4903
# Epoch 314/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1050 - categorical_accuracy: 0.4710
# Epoch 315/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0552 - categorical_accuracy: 0.4952
# Epoch 316/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0453 - categorical_accuracy: 0.5217
# Epoch 317/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0378 - categorical_accuracy: 0.5217
# Epoch 318/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0531 - categorical_accuracy: 0.4831
# Epoch 319/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0434 - categorical_accuracy: 0.4758
# Epoch 320/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0642 - categorical_accuracy: 0.4976
# Epoch 321/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0639 - categorical_accuracy: 0.4469
# Epoch 322/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0206 - categorical_accuracy: 0.5266
# Epoch 323/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0569 - categorical_accuracy: 0.4976
# Epoch 324/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9862 - categorical_accuracy: 0.5338
# Epoch 325/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0593 - categorical_accuracy: 0.4758
# Epoch 326/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0613 - categorical_accuracy: 0.4928
# Epoch 327/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0566 - categorical_accuracy: 0.4903
# Epoch 328/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0777 - categorical_accuracy: 0.4758
# Epoch 329/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0216 - categorical_accuracy: 0.5266
# Epoch 330/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0778 - categorical_accuracy: 0.4976
# Epoch 331/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9722 - categorical_accuracy: 0.5314
# Epoch 332/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0060 - categorical_accuracy: 0.5193
# Epoch 333/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0721 - categorical_accuracy: 0.4734
# Epoch 334/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9807 - categorical_accuracy: 0.5362
# Epoch 335/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0585 - categorical_accuracy: 0.4686
# Epoch 336/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0170 - categorical_accuracy: 0.5121
# Epoch 337/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0935 - categorical_accuracy: 0.4638
# Epoch 338/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1169 - categorical_accuracy: 0.4517
# Epoch 339/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0623 - categorical_accuracy: 0.4831
# Epoch 340/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9940 - categorical_accuracy: 0.5121
# Epoch 341/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0686 - categorical_accuracy: 0.5169
# Epoch 342/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0874 - categorical_accuracy: 0.5000
# Epoch 343/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0095 - categorical_accuracy: 0.5024
# Epoch 344/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9809 - categorical_accuracy: 0.5097
# Epoch 345/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0260 - categorical_accuracy: 0.5048
# Epoch 346/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0776 - categorical_accuracy: 0.4662
# Epoch 347/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1013 - categorical_accuracy: 0.4493
# Epoch 348/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9921 - categorical_accuracy: 0.5024
# Epoch 349/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0631 - categorical_accuracy: 0.4517
# Epoch 350/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0053 - categorical_accuracy: 0.5169
# Epoch 351/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0534 - categorical_accuracy: 0.4855
# Epoch 352/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0171 - categorical_accuracy: 0.5000
# Epoch 353/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9867 - categorical_accuracy: 0.5266
# Epoch 354/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0348 - categorical_accuracy: 0.5290
# Epoch 355/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0875 - categorical_accuracy: 0.4976
# Epoch 356/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0908 - categorical_accuracy: 0.4855
# Epoch 357/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0953 - categorical_accuracy: 0.4879
# Epoch 358/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9995 - categorical_accuracy: 0.5459
# Epoch 359/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0009 - categorical_accuracy: 0.5266
# Epoch 360/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0909 - categorical_accuracy: 0.4734
# Epoch 361/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0201 - categorical_accuracy: 0.5097
# Epoch 362/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1013 - categorical_accuracy: 0.4807
# Epoch 363/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0922 - categorical_accuracy: 0.4807
# Epoch 364/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0697 - categorical_accuracy: 0.4662
# Epoch 365/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0668 - categorical_accuracy: 0.4783
# Epoch 366/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9803 - categorical_accuracy: 0.5362
# Epoch 367/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0236 - categorical_accuracy: 0.4928
# Epoch 368/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0529 - categorical_accuracy: 0.4807
# Epoch 369/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0087 - categorical_accuracy: 0.5097
# Epoch 370/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0446 - categorical_accuracy: 0.5097
# Epoch 371/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0840 - categorical_accuracy: 0.4734
# Epoch 372/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0239 - categorical_accuracy: 0.4879
# Epoch 373/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0545 - categorical_accuracy: 0.4903
# Epoch 374/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1102 - categorical_accuracy: 0.4565
# Epoch 375/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0753 - categorical_accuracy: 0.4976
# Epoch 376/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0216 - categorical_accuracy: 0.4855
# Epoch 377/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0644 - categorical_accuracy: 0.4855
# Epoch 378/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0587 - categorical_accuracy: 0.4976
# Epoch 379/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0479 - categorical_accuracy: 0.5048
# Epoch 380/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1025 - categorical_accuracy: 0.4734
# Epoch 381/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0227 - categorical_accuracy: 0.5024
# Epoch 382/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1104 - categorical_accuracy: 0.4372
# Epoch 383/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0562 - categorical_accuracy: 0.5072
# Epoch 384/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9722 - categorical_accuracy: 0.5290
# Epoch 385/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0809 - categorical_accuracy: 0.5024
# Epoch 386/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0560 - categorical_accuracy: 0.4903
# Epoch 387/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0406 - categorical_accuracy: 0.4976
# Epoch 388/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0412 - categorical_accuracy: 0.4614
# Epoch 389/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0997 - categorical_accuracy: 0.4903
# Epoch 390/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0885 - categorical_accuracy: 0.4710
# Epoch 391/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0419 - categorical_accuracy: 0.4879
# Epoch 392/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0469 - categorical_accuracy: 0.5266
# Epoch 393/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0169 - categorical_accuracy: 0.5121
# Epoch 394/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0751 - categorical_accuracy: 0.4758
# Epoch 395/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0490 - categorical_accuracy: 0.4928
# Epoch 396/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0627 - categorical_accuracy: 0.4928
# Epoch 397/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0319 - categorical_accuracy: 0.5000
# Epoch 398/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9655 - categorical_accuracy: 0.5435
# Epoch 399/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0927 - categorical_accuracy: 0.4565
# Epoch 400/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0869 - categorical_accuracy: 0.4662
# Epoch 401/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0594 - categorical_accuracy: 0.4928
# Epoch 402/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9778 - categorical_accuracy: 0.5000
# Epoch 403/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0620 - categorical_accuracy: 0.4928
# Epoch 404/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0121 - categorical_accuracy: 0.4903
# Epoch 405/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0021 - categorical_accuracy: 0.4976
# Epoch 406/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0219 - categorical_accuracy: 0.5024
# Epoch 407/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1002 - categorical_accuracy: 0.4928
# Epoch 408/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0545 - categorical_accuracy: 0.4734
# Epoch 409/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0093 - categorical_accuracy: 0.5145
# ...
# Epoch 865/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9682 - categorical_accuracy: 0.5580
# Epoch 866/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0348 - categorical_accuracy: 0.4783
# Epoch 867/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0197 - categorical_accuracy: 0.4903
# Epoch 868/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1063 - categorical_accuracy: 0.4662
# Epoch 869/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0538 - categorical_accuracy: 0.4831
# Epoch 870/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0037 - categorical_accuracy: 0.5242
# Epoch 871/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0782 - categorical_accuracy: 0.4783
# Epoch 872/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0421 - categorical_accuracy: 0.5048
# Epoch 873/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0483 - categorical_accuracy: 0.4783
# Epoch 874/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0884 - categorical_accuracy: 0.4614
# Epoch 875/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1158 - categorical_accuracy: 0.4517
# Epoch 876/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0825 - categorical_accuracy: 0.4928
# Epoch 877/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0429 - categorical_accuracy: 0.4614
# Epoch 878/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0441 - categorical_accuracy: 0.5000
# Epoch 879/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0457 - categorical_accuracy: 0.4783
# Epoch 880/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0867 - categorical_accuracy: 0.4638
# Epoch 881/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1227 - categorical_accuracy: 0.4783
# Epoch 882/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0037 - categorical_accuracy: 0.5338
# Epoch 883/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0071 - categorical_accuracy: 0.5242
# Epoch 884/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0702 - categorical_accuracy: 0.4903
# Epoch 885/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0502 - categorical_accuracy: 0.4710
# Epoch 886/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0214 - categorical_accuracy: 0.5169
# Epoch 887/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1211 - categorical_accuracy: 0.4976
# Epoch 888/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0076 - categorical_accuracy: 0.5290
# Epoch 889/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0535 - categorical_accuracy: 0.5072
# Epoch 890/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0370 - categorical_accuracy: 0.4928
# Epoch 891/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0517 - categorical_accuracy: 0.4807
# Epoch 892/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0882 - categorical_accuracy: 0.4952
# Epoch 893/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1631 - categorical_accuracy: 0.4662
# Epoch 894/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0576 - categorical_accuracy: 0.5072
# Epoch 895/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0268 - categorical_accuracy: 0.5024
# Epoch 896/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0846 - categorical_accuracy: 0.4783
# Epoch 897/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0523 - categorical_accuracy: 0.4976
# Epoch 898/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0883 - categorical_accuracy: 0.4758
# Epoch 899/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0248 - categorical_accuracy: 0.4662
# Epoch 900/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0852 - categorical_accuracy: 0.4662
# Epoch 901/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0209 - categorical_accuracy: 0.4686
# Epoch 902/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0250 - categorical_accuracy: 0.4903
# Epoch 903/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0242 - categorical_accuracy: 0.4783
# Epoch 904/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0898 - categorical_accuracy: 0.4734
# Epoch 905/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1229 - categorical_accuracy: 0.4420
# Epoch 906/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0049 - categorical_accuracy: 0.5145
# Epoch 907/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0780 - categorical_accuracy: 0.4686
# Epoch 908/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0726 - categorical_accuracy: 0.4686
# Epoch 909/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0500 - categorical_accuracy: 0.4638
# Epoch 910/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9841 - categorical_accuracy: 0.5217
# Epoch 911/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0025 - categorical_accuracy: 0.5097
# Epoch 912/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0925 - categorical_accuracy: 0.4662
# Epoch 913/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0683 - categorical_accuracy: 0.5000
# Epoch 914/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0000 - categorical_accuracy: 0.5217
# Epoch 915/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0335 - categorical_accuracy: 0.5217
# Epoch 916/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0515 - categorical_accuracy: 0.4807
# Epoch 917/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0322 - categorical_accuracy: 0.4831
# Epoch 918/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0701 - categorical_accuracy: 0.4758
# Epoch 919/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0501 - categorical_accuracy: 0.4928
# Epoch 920/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0301 - categorical_accuracy: 0.5072
# Epoch 921/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0275 - categorical_accuracy: 0.4928
# Epoch 922/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0249 - categorical_accuracy: 0.5145
# Epoch 923/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9943 - categorical_accuracy: 0.5169
# Epoch 924/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0995 - categorical_accuracy: 0.4734
# Epoch 925/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0041 - categorical_accuracy: 0.5000
# Epoch 926/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0004 - categorical_accuracy: 0.5217
# Epoch 927/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0932 - categorical_accuracy: 0.4686
# Epoch 928/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1345 - categorical_accuracy: 0.4565
# Epoch 929/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0715 - categorical_accuracy: 0.4686
# Epoch 930/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0725 - categorical_accuracy: 0.4903
# Epoch 931/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1229 - categorical_accuracy: 0.4324
# Epoch 932/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0326 - categorical_accuracy: 0.4831
# Epoch 933/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0822 - categorical_accuracy: 0.5000
# Epoch 934/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0978 - categorical_accuracy: 0.4734
# Epoch 935/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0349 - categorical_accuracy: 0.4952
# Epoch 936/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0995 - categorical_accuracy: 0.4348
# Epoch 937/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0420 - categorical_accuracy: 0.5121
# Epoch 938/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0178 - categorical_accuracy: 0.4879
# Epoch 939/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0512 - categorical_accuracy: 0.5145
# Epoch 940/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0363 - categorical_accuracy: 0.5169
# Epoch 941/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0769 - categorical_accuracy: 0.4758
# Epoch 942/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0621 - categorical_accuracy: 0.4686
# Epoch 943/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0871 - categorical_accuracy: 0.4758
# Epoch 944/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0736 - categorical_accuracy: 0.4686
# Epoch 945/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0936 - categorical_accuracy: 0.4469
# Epoch 946/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0819 - categorical_accuracy: 0.4686
# Epoch 947/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1691 - categorical_accuracy: 0.4179
# Epoch 948/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0955 - categorical_accuracy: 0.4807
# Epoch 949/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0636 - categorical_accuracy: 0.4831
# Epoch 950/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0867 - categorical_accuracy: 0.5024
# Epoch 951/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0991 - categorical_accuracy: 0.4807
# Epoch 952/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0804 - categorical_accuracy: 0.4807
# Epoch 953/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0931 - categorical_accuracy: 0.4638
# Epoch 954/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0279 - categorical_accuracy: 0.5217
# Epoch 955/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0272 - categorical_accuracy: 0.5169
# Epoch 956/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0613 - categorical_accuracy: 0.4807
# Epoch 957/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0318 - categorical_accuracy: 0.4952
# Epoch 958/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0082 - categorical_accuracy: 0.5024
# Epoch 959/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9826 - categorical_accuracy: 0.5386
# Epoch 960/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0278 - categorical_accuracy: 0.4879
# Epoch 961/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0825 - categorical_accuracy: 0.4686
# Epoch 962/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0009 - categorical_accuracy: 0.5483
# Epoch 963/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0976 - categorical_accuracy: 0.4903
# Epoch 964/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0658 - categorical_accuracy: 0.4855
# Epoch 965/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0479 - categorical_accuracy: 0.4855
# Epoch 966/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0204 - categorical_accuracy: 0.4928
# Epoch 967/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0456 - categorical_accuracy: 0.4903
# Epoch 968/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0433 - categorical_accuracy: 0.5048
# Epoch 969/1000
# 104/104 [==============================] - 148s 1s/step - loss: 0.9984 - categorical_accuracy: 0.5290
# Epoch 970/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0085 - categorical_accuracy: 0.5217
# Epoch 971/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.1750 - categorical_accuracy: 0.4300
# Epoch 972/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0478 - categorical_accuracy: 0.5024
# Epoch 973/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0283 - categorical_accuracy: 0.5000
# Epoch 974/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0768 - categorical_accuracy: 0.4758
# Epoch 975/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0865 - categorical_accuracy: 0.5072
# Epoch 976/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0545 - categorical_accuracy: 0.4831
# Epoch 977/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0513 - categorical_accuracy: 0.5048
# Epoch 978/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1296 - categorical_accuracy: 0.4469
# Epoch 979/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0773 - categorical_accuracy: 0.4976
# Epoch 980/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9834 - categorical_accuracy: 0.5193
# Epoch 981/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9898 - categorical_accuracy: 0.4928
# Epoch 982/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1014 - categorical_accuracy: 0.4710
# Epoch 983/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0429 - categorical_accuracy: 0.4710
# Epoch 984/1000
# 104/104 [==============================] - 149s 1s/step - loss: 0.9982 - categorical_accuracy: 0.5266
# Epoch 985/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0540 - categorical_accuracy: 0.4710
# Epoch 986/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0247 - categorical_accuracy: 0.5121
# Epoch 987/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0264 - categorical_accuracy: 0.5000
# Epoch 988/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0489 - categorical_accuracy: 0.5097
# Epoch 989/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0267 - categorical_accuracy: 0.4879
# Epoch 990/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0108 - categorical_accuracy: 0.5266
# Epoch 991/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0930 - categorical_accuracy: 0.4589
# Epoch 992/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0445 - categorical_accuracy: 0.5024
# Epoch 993/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1228 - categorical_accuracy: 0.4541
# Epoch 994/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0617 - categorical_accuracy: 0.5121
# Epoch 995/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0572 - categorical_accuracy: 0.4831
# Epoch 996/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0955 - categorical_accuracy: 0.4493
# Epoch 997/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.0533 - categorical_accuracy: 0.5000
# Epoch 998/1000
# 104/104 [==============================] - 148s 1s/step - loss: 1.1066 - categorical_accuracy: 0.4565
# Epoch 999/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0986 - categorical_accuracy: 0.4952
# Epoch 1000/1000
# 104/104 [==============================] - 149s 1s/step - loss: 1.0487 - categorical_accuracy: 0.5121
